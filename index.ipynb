# %% [markdown]
# # Applying Gradient Descent Lab

# %% [markdown]
# ### Introduction

# %% [markdown]
# In this lesson, let's put our knowledge about data science to the test. We will have access to functions in the [error](https://github.com/learn-co-curriculum/applying-gradient-descent-lab/blob/master/error.py), [graph](https://github.com/learn-co-curriculum/applying-gradient-descent-lab/blob/master/graph.py) and [linear equations](https://github.com/learn-co-curriculum/applying-gradient-descent-lab/blob/master/linear_equations.py) libraries that we previously wrote.
#
# This is our task. We are an employee for *Good Lion Studios*. For *Good Lion*, our job is first to gather, explore, and format our data so that we can build a regression line of this data. Then we will work through various attempts of building out these regression lines. By the end of this lab, we should have a working version that we can proudly show to our manager.

# %% [markdown]
# ### Learning Objectives

# %% [markdown]
# * Review how to use built-in functions, like filter and map, to clean data
# * Evaluate the quality of regression lines using Residual Sum of Squares (RSS)
# * Review how RSS changes with varying values of slope and y-intercept of a regression line
# * Implement gradient descent to find a "best fit" regression line
#
# This lesson is an opportunity to review the concepts explained in our introduction to machine learning section and practice what we recently learned about gradient descent to find an optimal regression line.
#
# > ****Use the round method****: For many of the methods, we round down the return value to two decimal places. We can do so by using the **round** function, as in **round(12.1212, 2)** to round 12.1212 to 12.12. We did this to allow for slight differences between our results and expectations. So when we see our data differing from the expectation in the tests, check if using the **round** function helps.

# %% [markdown]
# ### Determining Quality

# %% [markdown]
# #### Retrieve the data
#
# First, let's get some movies from the FiveThirtyEight dataset [provided here](https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv).  The code below parses this data from the csv file and saves it to the `movies` variable as a list of dictionaries.

# %%
import pandas

def parse_file(fileName):
    movies_df = pandas.read_csv(fileName)
    return movies_df.to_dict('records')

movies = parse_file('https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv')

# %%
type(movies) # list
len(movies) # 1794
# Out:
# 1794

# %% [markdown]
# As you can see, this list is full of 1794 dictionaries, each one representing a movie.

# %% [markdown]
# #### Explore the data
#
#
# Let's take a look at that first movie in the dataset.

# %%
movies[0]
# Out:
# {'year': 2013,
#  'imdb': 'tt1711425',
#  'title': '21 &amp; Over',
#  'test': 'notalk',
#  'clean_test': 'notalk',
#  'binary': 'FAIL',
#  'budget': 13000000,
#  'domgross': 25682380.0,
#  'intgross': 42195766.0,
#  'code': '2013FAIL',
#  'budget_2013$': 13000000,
#  'domgross_2013$': 25682380.0,
#  'intgross_2013$': 42195766.0,
#  'period code': 1.0,
#  'decade code': 1.0}

# %% [markdown]
# Here we can see the data available for each movie. The information most relevant for our task is:
#
# 1. `budget_2013$` is the budget adjusted for inflation in 2013 dollars
# 2. `domgross_2013$` is the domestic revenue adjusted for inflation in 2013 dollars
# 3. `intgross_2013$` is the international revenue adjusted for inflation in 2013 dollars

# %% [markdown]
# ### Cleaning our data

# %% [markdown]
# #### 1. Handle missing data
#
# Now, let's look at the values associated with these attributes.  The first movie looks good since it has nice data for each of these attributes. Unfortunately, the data for some other movies might not be so fun to play with. Let's remove the movies whose `domgross_2013` points to values of `nan`, which stands for "not a number". This data is missing.  There are only a few pieces of missing data here, so we can safely remove these movies without causing too much damage.

# %%
import math
list(filter(lambda movie: math.isnan(movie['domgross_2013$']), movies))
# Out:
# [{'year': 2013,
#   'imdb': 'tt2005374',
#   'title': 'The Frozen Ground',
#   'test': 'nowomen-disagree',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 19200000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2013FAIL',
#   'budget_2013$': 19200000,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2011,
#   'imdb': 'tt1422136',
#   'title': 'A Lonely Place to Die',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 4000000,
#   'domgross': nan,
#   'intgross': 442550.0,
#   'code': '2011PASS',
#   'budget_2013$': 4142763,
#   'domgross_2013$': nan,
#   'intgross_2013$': 458345.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2011,
#   'imdb': 'tt1701990',
#   'title': 'Detention',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 10000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2011PASS',
#   'budget_2013$': 10356908,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2010,
#   'imdb': 'tt1216520',
#   'title': 'Womb',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 13000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2010PASS',
#   'budget_2013$': 13887014,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2009,
#   'imdb': 'tt1024744',
#   'title': 'I Come with the Rain',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 18000000,
#   'domgross': 0.0,
#   'intgross': 627422.0,
#   'code': '2009FAIL',
#   'budget_2013$': 19543169,
#   'domgross_2013$': nan,
#   'intgross_2013$': 681212.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2009,
#   'imdb': 'tt1068678',
#   'title': 'Veronika Decides to Die',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 9000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2009PASS',
#   'budget_2013$': 9771584,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2009,
#   'imdb': 'tt0448182',
#   'title': 'Yesterday Was a Lie',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 200000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2009PASS',
#   'budget_2013$': 217146,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2008,
#   'imdb': 'tt0489018',
#   'title': 'Day of the Dead',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 18000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2008PASS',
#   'budget_2013$': 19480614,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2008,
#   'imdb': 'tt0942903',
#   'title': 'Stargate: The Ark of Truth',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 7000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2008FAIL',
#   'budget_2013$': 7575794,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2008,
#   'imdb': 'tt0882978',
#   'title': 'Three Kingdoms: Resurrection of the Dragon',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 20000000,
#   'domgross': nan,
#   'intgross': 22139590.0,
#   'code': '2008FAIL',
#   'budget_2013$': 21645126,
#   'domgross_2013$': nan,
#   'intgross_2013$': 23960711.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2007,
#   'imdb': 'tt1038988',
#   'title': '[Rec]',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 2100000,
#   'domgross': nan,
#   'intgross': 27117954.0,
#   'code': '2007PASS',
#   'budget_2013$': 2359441,
#   'domgross_2013$': nan,
#   'intgross_2013$': 30468201.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2007,
#   'imdb': 'tt0756683',
#   'title': 'The Man from Earth',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 200000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '2007FAIL',
#   'budget_2013$': 224709,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2007,
#   'imdb': 'tt0496436',
#   'title': 'White Noise 2: The Light',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 10000000,
#   'domgross': nan,
#   'intgross': 8243567.0,
#   'code': '2007FAIL',
#   'budget_2013$': 11235435,
#   'domgross_2013$': nan,
#   'intgross_2013$': 9262006.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2006,
#   'imdb': 'tt0416496',
#   'title': 'Bandidas',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 35000000,
#   'domgross': nan,
#   'intgross': 18400000.0,
#   'code': '2006PASS',
#   'budget_2013$': 40452872,
#   'domgross_2013$': nan,
#   'intgross_2013$': 21266653.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 2006,
#   'imdb': 'tt0490166',
#   'title': 'London To Brighton',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 825000,
#   'domgross': nan,
#   'intgross': 610776.0,
#   'code': '2006PASS',
#   'budget_2013$': 953532,
#   'domgross_2013$': nan,
#   'intgross_2013$': 705933.0,
#   'period code': 2.0,
#   'decade code': 2.0},
#  {'year': 1985,
#   'imdb': 'tt0088993',
#   'title': 'Day of the Dead',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 18000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '1985FAIL',
#   'budget_2013$': 38971004,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': nan,
#   'decade code': nan},
#  {'year': 1985,
#   'imdb': 'tt0091578',
#   'title': 'My Beautiful Laundrette',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 400000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '1985FAIL',
#   'budget_2013$': 866022,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': nan,
#   'decade code': nan},
#  {'year': 1972,
#   'imdb': 'tt0068156',
#   'title': '1776',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 4000000,
#   'domgross': nan,
#   'intgross': nan,
#   'code': '1972FAIL',
#   'budget_2013$': 22288557,
#   'domgross_2013$': nan,
#   'intgross_2013$': nan,
#   'period code': nan,
#   'decade code': nan}]

# %% [markdown]
# Write a function called `remove_movies_missing_data` that returns the subset of movies that don't have `nan`.
#
# > To do so, you can import the math library and make use of the `math.isnan` method.  More information about this method can be [found here](https://stackoverflow.com/questions/944700/how-can-i-check-for-nan-in-python).

# %%
import math

def remove_movies_missing_data(movies):
    return list(filter(lambda movie: not math.isnan(movie['domgross_2013$']), movies))

# %%
parsed_movies = remove_movies_missing_data(movies) or []

# %%
parsed_movies
# Out:
# [{'year': 2013,
#   'imdb': 'tt1711425',
#   'title': '21 &amp; Over',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 13.0,
#   'domgross': 25.68,
#   'intgross': 42.2,
#   'code': '2013FAIL',
#   'budget_2013$': 13.0,
#   'domgross_2013$': 25.68,
#   'intgross_2013$': 42.2,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1343727',
#   'title': 'Dredd 3D',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 45.0,
#   'domgross': 13.41,
#   'intgross': 40.87,
#   'code': '2012PASS',
#   'budget_2013$': 45.66,
#   'domgross_2013$': 13.61,
#   'intgross_2013$': 41.47,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2024544',
#   'title': '12 Years a Slave',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 20.0,
#   'domgross': 53.11,
#   'intgross': 158.61,
#   'code': '2013FAIL',
#   'budget_2013$': 20.0,
#   'domgross_2013$': 53.11,
#   'intgross_2013$': 158.61,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1272878',
#   'title': '2 Guns',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 61.0,
#   'domgross': 75.61,
#   'intgross': 132.49,
#   'code': '2013FAIL',
#   'budget_2013$': 61.0,
#   'domgross_2013$': 75.61,
#   'intgross_2013$': 132.49,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0453562',
#   'title': '42',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 40.0,
#   'domgross': 95.02,
#   'intgross': 95.02,
#   'code': '2013FAIL',
#   'budget_2013$': 40.0,
#   'domgross_2013$': 95.02,
#   'intgross_2013$': 95.02,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1335975',
#   'title': '47 Ronin',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 225.0,
#   'domgross': 38.36,
#   'intgross': 145.8,
#   'code': '2013FAIL',
#   'budget_2013$': 225.0,
#   'domgross_2013$': 38.36,
#   'intgross_2013$': 145.8,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1606378',
#   'title': 'A Good Day to Die Hard',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 92.0,
#   'domgross': 67.35,
#   'intgross': 304.25,
#   'code': '2013FAIL',
#   'budget_2013$': 92.0,
#   'domgross_2013$': 67.35,
#   'intgross_2013$': 304.25,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2194499',
#   'title': 'About Time',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 12.0,
#   'domgross': 15.32,
#   'intgross': 87.32,
#   'code': '2013PASS',
#   'budget_2013$': 12.0,
#   'domgross_2013$': 15.32,
#   'intgross_2013$': 87.32,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1814621',
#   'title': 'Admission',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 13.0,
#   'domgross': 18.01,
#   'intgross': 18.01,
#   'code': '2013PASS',
#   'budget_2013$': 13.0,
#   'domgross_2013$': 18.01,
#   'intgross_2013$': 18.01,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1815862',
#   'title': 'After Earth',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 130.0,
#   'domgross': 60.52,
#   'intgross': 244.37,
#   'code': '2013FAIL',
#   'budget_2013$': 130.0,
#   'domgross_2013$': 60.52,
#   'intgross_2013$': 244.37,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1800241',
#   'title': 'American Hustle',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 40.0,
#   'domgross': 148.43,
#   'intgross': 249.48,
#   'code': '2013PASS',
#   'budget_2013$': 40.0,
#   'domgross_2013$': 148.43,
#   'intgross_2013$': 249.48,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1322269',
#   'title': 'August: Osage County',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 25.0,
#   'domgross': 37.3,
#   'intgross': 50.3,
#   'code': '2013PASS',
#   'budget_2013$': 25.0,
#   'domgross_2013$': 37.3,
#   'intgross_2013$': 50.3,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1559547',
#   'title': 'Beautiful Creatures',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 50.0,
#   'domgross': 19.45,
#   'intgross': 55.94,
#   'code': '2013PASS',
#   'budget_2013$': 50.0,
#   'domgross_2013$': 19.45,
#   'intgross_2013$': 55.94,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2334873',
#   'title': 'Blue Jasmine',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 18.0,
#   'domgross': 33.35,
#   'intgross': 68.45,
#   'code': '2013PASS',
#   'budget_2013$': 18.0,
#   'domgross_2013$': 33.35,
#   'intgross_2013$': 68.45,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1535109',
#   'title': 'Captain Phillips',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 55.0,
#   'domgross': 107.14,
#   'intgross': 218.74,
#   'code': '2013FAIL',
#   'budget_2013$': 55.0,
#   'domgross_2013$': 107.14,
#   'intgross_2013$': 218.74,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1939659',
#   'title': 'Carrie',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 30.0,
#   'domgross': 35.27,
#   'intgross': 85.0,
#   'code': '2013PASS',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 35.27,
#   'intgross_2013$': 85.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1985966',
#   'title': 'Cloudy with a Chance of Meatballs 2',
#   'test': 'nowomen-disagree',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 78.0,
#   'domgross': 119.64,
#   'intgross': 271.73,
#   'code': '2013FAIL',
#   'budget_2013$': 78.0,
#   'domgross_2013$': 119.64,
#   'intgross_2013$': 271.73,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1690953',
#   'title': 'Despicable Me 2',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 76.0,
#   'domgross': 368.07,
#   'intgross': 970.77,
#   'code': '2013PASS',
#   'budget_2013$': 76.0,
#   'domgross_2013$': 368.07,
#   'intgross_2013$': 970.77,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2229499',
#   'title': 'Don Jon',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 5.5,
#   'domgross': 24.48,
#   'intgross': 26.38,
#   'code': '2013FAIL',
#   'budget_2013$': 5.5,
#   'domgross_2013$': 24.48,
#   'intgross_2013$': 26.38,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1535108',
#   'title': 'Elysium',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 120.0,
#   'domgross': 93.05,
#   'intgross': 286.19,
#   'code': '2013PASS',
#   'budget_2013$': 120.0,
#   'domgross_2013$': 93.05,
#   'intgross_2013$': 286.19,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1731141',
#   'title': 'Ender&#39;s Game',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 110.0,
#   'domgross': 61.74,
#   'intgross': 89.74,
#   'code': '2013FAIL',
#   'budget_2013$': 110.0,
#   'domgross_2013$': 61.74,
#   'intgross_2013$': 89.74,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0848537',
#   'title': 'Epic',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 100.0,
#   'domgross': 107.52,
#   'intgross': 268.42,
#   'code': '2013PASS',
#   'budget_2013$': 100.0,
#   'domgross_2013$': 107.52,
#   'intgross_2013$': 268.42,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0765446',
#   'title': 'Escape from Planet Earth',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 40.0,
#   'domgross': 57.01,
#   'intgross': 66.45,
#   'code': '2013PASS',
#   'budget_2013$': 40.0,
#   'domgross_2013$': 57.01,
#   'intgross_2013$': 66.45,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1211956',
#   'title': 'Escape Plan',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 70.0,
#   'domgross': 25.21,
#   'intgross': 103.81,
#   'code': '2013FAIL',
#   'budget_2013$': 70.0,
#   'domgross_2013$': 25.21,
#   'intgross_2013$': 103.81,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1288558',
#   'title': 'Evil Dead',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 17.0,
#   'domgross': 54.24,
#   'intgross': 97.4,
#   'code': '2013PASS',
#   'budget_2013$': 17.0,
#   'domgross_2013$': 54.24,
#   'intgross_2013$': 97.4,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1905041',
#   'title': 'Fast and Furious 6',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 160.0,
#   'domgross': 238.68,
#   'intgross': 788.13,
#   'code': '2013PASS',
#   'budget_2013$': 160.0,
#   'domgross_2013$': 238.68,
#   'intgross_2013$': 788.13,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2294629',
#   'title': 'Frozen',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 150.0,
#   'domgross': 393.05,
#   'intgross': 1004.55,
#   'code': '2013PASS',
#   'budget_2013$': 150.0,
#   'domgross_2013$': 393.05,
#   'intgross_2013$': 1004.55,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1583421',
#   'title': 'G.I. Joe: Retaliation',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 140.0,
#   'domgross': 122.52,
#   'intgross': 371.92,
#   'code': '2013PASS',
#   'budget_2013$': 140.0,
#   'domgross_2013$': 122.52,
#   'intgross_2013$': 371.92,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1321870',
#   'title': 'Gangster Squad',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 60.0,
#   'domgross': 46.0,
#   'intgross': 104.1,
#   'code': '2013FAIL',
#   'budget_2013$': 60.0,
#   'domgross_2013$': 46.0,
#   'intgross_2013$': 104.1,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2425486',
#   'title': 'Gloria',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 30.0,
#   'domgross': 4.17,
#   'intgross': 4.97,
#   'code': '2013PASS',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 4.17,
#   'intgross_2013$': 4.97,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1454468',
#   'title': 'Gravity',
#   'test': 'nowomen-disagree',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 110.0,
#   'domgross': 271.81,
#   'intgross': 708.71,
#   'code': '2013FAIL',
#   'budget_2013$': 110.0,
#   'domgross_2013$': 271.81,
#   'intgross_2013$': 708.71,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2191701',
#   'title': 'Grown Ups 2',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 80.0,
#   'domgross': 133.67,
#   'intgross': 247.02,
#   'code': '2013FAIL',
#   'budget_2013$': 80.0,
#   'domgross_2013$': 133.67,
#   'intgross_2013$': 247.02,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1428538',
#   'title': 'Hansel &amp; Gretel: Witch Hunters',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 50.0,
#   'domgross': 55.7,
#   'intgross': 225.7,
#   'code': '2013PASS',
#   'budget_2013$': 50.0,
#   'domgross_2013$': 55.7,
#   'intgross_2013$': 225.7,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1798709',
#   'title': 'Her',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 23.0,
#   'domgross': 25.0,
#   'intgross': 33.03,
#   'code': '2013FAIL',
#   'budget_2013$': 23.0,
#   'domgross_2013$': 25.0,
#   'intgross_2013$': 33.03,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2024432',
#   'title': 'Identity Thief',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 35.0,
#   'domgross': 134.51,
#   'intgross': 176.27,
#   'code': '2013FAIL',
#   'budget_2013$': 35.0,
#   'domgross_2013$': 134.51,
#   'intgross_2013$': 176.27,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2226417',
#   'title': 'Insidious: Chapter 2',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 5.0,
#   'domgross': 83.59,
#   'intgross': 161.91,
#   'code': '2013FAIL',
#   'budget_2013$': 5.0,
#   'domgross_2013$': 83.59,
#   'intgross_2013$': 161.91,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1300854',
#   'title': 'Iron Man 3',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 200.0,
#   'domgross': 408.99,
#   'intgross': 1212.69,
#   'code': '2013FAIL',
#   'budget_2013$': 200.0,
#   'domgross_2013$': 408.99,
#   'intgross_2013$': 1212.69,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1351685',
#   'title': 'Jack the Giant Slayer',
#   'test': 'nowomen-disagree',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 195.0,
#   'domgross': 65.19,
#   'intgross': 197.39,
#   'code': '2013FAIL',
#   'budget_2013$': 195.0,
#   'domgross_2013$': 65.19,
#   'intgross_2013$': 197.39,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1650554',
#   'title': 'Kick-Ass 2',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 28.0,
#   'domgross': 28.8,
#   'intgross': 60.84,
#   'code': '2013PASS',
#   'budget_2013$': 28.0,
#   'domgross_2013$': 28.8,
#   'intgross_2013$': 60.84,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1204975',
#   'title': 'Last Vegas',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 28.0,
#   'domgross': 63.91,
#   'intgross': 112.91,
#   'code': '2013FAIL',
#   'budget_2013$': 28.0,
#   'domgross_2013$': 63.91,
#   'intgross_2013$': 112.91,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1327773',
#   'title': 'Lee Daniels&#39; The Butler',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 30.0,
#   'domgross': 116.63,
#   'intgross': 151.51,
#   'code': '2013PASS',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 116.63,
#   'intgross_2013$': 151.51,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2002718',
#   'title': 'Machete Kills',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 2.0,
#   'domgross': 8.01,
#   'intgross': 9.41,
#   'code': '2013PASS',
#   'budget_2013$': 2.0,
#   'domgross_2013$': 8.01,
#   'intgross_2013$': 9.41,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2023587',
#   'title': 'Mama',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 15.0,
#   'domgross': 71.63,
#   'intgross': 148.04,
#   'code': '2013PASS',
#   'budget_2013$': 15.0,
#   'domgross_2013$': 71.63,
#   'intgross_2013$': 148.04,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0770828',
#   'title': 'Man of Steel',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 225.0,
#   'domgross': 291.05,
#   'intgross': 688.0,
#   'code': '2013PASS',
#   'budget_2013$': 225.0,
#   'domgross_2013$': 291.05,
#   'intgross_2013$': 688.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1821549',
#   'title': 'Nebraska',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 12.0,
#   'domgross': 17.48,
#   'intgross': 17.48,
#   'code': '2013PASS',
#   'budget_2013$': 12.0,
#   'domgross_2013$': 17.48,
#   'intgross_2013$': 17.48,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1670345',
#   'title': 'Now You See Me',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 75.0,
#   'domgross': 117.72,
#   'intgross': 351.72,
#   'code': '2013FAIL',
#   'budget_2013$': 75.0,
#   'domgross_2013$': 117.72,
#   'intgross_2013$': 351.72,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1483013',
#   'title': 'Oblivion',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 120.0,
#   'domgross': 89.11,
#   'intgross': 287.54,
#   'code': '2013FAIL',
#   'budget_2013$': 120.0,
#   'domgross_2013$': 89.11,
#   'intgross_2013$': 287.54,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2302755',
#   'title': 'Olympus Has Fallen',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 70.0,
#   'domgross': 98.93,
#   'intgross': 150.56,
#   'code': '2013FAIL',
#   'budget_2013$': 70.0,
#   'domgross_2013$': 98.93,
#   'intgross_2013$': 150.56,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1623205',
#   'title': 'Oz the Great and Powerful',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 200.0,
#   'domgross': 234.77,
#   'intgross': 489.57,
#   'code': '2013PASS',
#   'budget_2013$': 200.0,
#   'domgross_2013$': 234.77,
#   'intgross_2013$': 489.57,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1663662',
#   'title': 'Pacific Rim',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 190.0,
#   'domgross': 101.8,
#   'intgross': 411.0,
#   'code': '2013FAIL',
#   'budget_2013$': 190.0,
#   'domgross_2013$': 101.8,
#   'intgross_2013$': 411.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1980209',
#   'title': 'Pain &amp; Gain',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 26.0,
#   'domgross': 49.88,
#   'intgross': 81.28,
#   'code': '2013FAIL',
#   'budget_2013$': 26.0,
#   'domgross_2013$': 49.88,
#   'intgross_2013$': 81.28,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1904996',
#   'title': 'Parker',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 35.0,
#   'domgross': 17.62,
#   'intgross': 46.35,
#   'code': '2013PASS',
#   'budget_2013$': 35.0,
#   'domgross_2013$': 17.62,
#   'intgross_2013$': 46.35,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1699755',
#   'title': 'Peeples',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 15.0,
#   'domgross': 9.18,
#   'intgross': 9.18,
#   'code': '2013FAIL',
#   'budget_2013$': 15.0,
#   'domgross_2013$': 9.18,
#   'intgross_2013$': 9.18,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1854564',
#   'title': 'Percy Jackson: Sea of Monsters',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 90.0,
#   'domgross': 68.56,
#   'intgross': 200.86,
#   'code': '2013PASS',
#   'budget_2013$': 90.0,
#   'domgross_2013$': 68.56,
#   'intgross_2013$': 200.86,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1392214',
#   'title': 'Prisoners',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 46.0,
#   'domgross': 61.0,
#   'intgross': 113.4,
#   'code': '2013PASS',
#   'budget_2013$': 46.0,
#   'domgross_2013$': 61.0,
#   'intgross_2013$': 113.4,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0790736',
#   'title': 'R.I.P.D.',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 130.0,
#   'domgross': 33.62,
#   'intgross': 79.02,
#   'code': '2013FAIL',
#   'budget_2013$': 130.0,
#   'domgross_2013$': 33.62,
#   'intgross_2013$': 79.02,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1821694',
#   'title': 'Red 2',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 84.0,
#   'domgross': 53.26,
#   'intgross': 137.16,
#   'code': '2013PASS',
#   'budget_2013$': 84.0,
#   'domgross_2013$': 53.26,
#   'intgross_2013$': 137.16,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1411250',
#   'title': 'Riddick',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 38.0,
#   'domgross': 42.03,
#   'intgross': 92.43,
#   'code': '2013FAIL',
#   'budget_2013$': 38.0,
#   'domgross_2013$': 42.03,
#   'intgross_2013$': 92.43,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2364841',
#   'title': 'Runner Runner',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 30.0,
#   'domgross': 19.32,
#   'intgross': 62.62,
#   'code': '2013FAIL',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 19.32,
#   'intgross_2013$': 62.62,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1979320',
#   'title': 'Rush',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 38.0,
#   'domgross': 26.95,
#   'intgross': 43.05,
#   'code': '2013FAIL',
#   'budget_2013$': 38.0,
#   'domgross_2013$': 26.95,
#   'intgross_2013$': 43.05,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1702439',
#   'title': 'Safe Haven',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 28.0,
#   'domgross': 71.4,
#   'intgross': 93.94,
#   'code': '2013PASS',
#   'budget_2013$': 28.0,
#   'domgross_2013$': 71.4,
#   'intgross_2013$': 93.94,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2140373',
#   'title': 'Saving Mr. Banks',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 35.0,
#   'domgross': 82.83,
#   'intgross': 100.73,
#   'code': '2013PASS',
#   'budget_2013$': 35.0,
#   'domgross_2013$': 82.83,
#   'intgross_2013$': 100.73,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2053463',
#   'title': 'Side Effects',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 30.0,
#   'domgross': 32.17,
#   'intgross': 60.29,
#   'code': '2013PASS',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 32.17,
#   'intgross_2013$': 60.29,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1408101',
#   'title': 'Star Trek Into Darkness',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 190.0,
#   'domgross': 228.78,
#   'intgross': 466.98,
#   'code': '2013FAIL',
#   'budget_2013$': 190.0,
#   'domgross_2013$': 228.78,
#   'intgross_2013$': 466.98,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1572315',
#   'title': 'Texas Chainsaw 3D',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 20.0,
#   'domgross': 34.34,
#   'intgross': 39.09,
#   'code': '2013PASS',
#   'budget_2013$': 20.0,
#   'domgross_2013$': 34.34,
#   'intgross_2013$': 39.09,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1931435',
#   'title': 'The Big Wedding',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 32.5,
#   'domgross': 21.82,
#   'intgross': 35.77,
#   'code': '2013PASS',
#   'budget_2013$': 32.5,
#   'domgross_2013$': 21.82,
#   'intgross_2013$': 35.77,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0816442',
#   'title': 'The Book Thief',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 19.0,
#   'domgross': 21.35,
#   'intgross': 62.05,
#   'code': '2013PASS',
#   'budget_2013$': 19.0,
#   'domgross_2013$': 21.35,
#   'intgross_2013$': 62.05,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1911644',
#   'title': 'The Call',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 13.0,
#   'domgross': 51.87,
#   'intgross': 58.94,
#   'code': '2013PASS',
#   'budget_2013$': 13.0,
#   'domgross_2013$': 51.87,
#   'intgross_2013$': 58.94,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1457767',
#   'title': 'The Conjuring',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 20.0,
#   'domgross': 137.4,
#   'intgross': 318.0,
#   'code': '2013PASS',
#   'budget_2013$': 20.0,
#   'domgross_2013$': 137.4,
#   'intgross_2013$': 318.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2193215',
#   'title': 'The Counselor',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 25.0,
#   'domgross': 16.97,
#   'intgross': 70.37,
#   'code': '2013PASS',
#   'budget_2013$': 25.0,
#   'domgross_2013$': 16.97,
#   'intgross_2013$': 70.37,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0481499',
#   'title': 'The Croods',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 135.0,
#   'domgross': 187.17,
#   'intgross': 573.07,
#   'code': '2013FAIL',
#   'budget_2013$': 135.0,
#   'domgross_2013$': 187.17,
#   'intgross_2013$': 573.07,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2404311',
#   'title': 'The Family',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 30.0,
#   'domgross': 36.92,
#   'intgross': 51.08,
#   'code': '2013FAIL',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 36.92,
#   'intgross_2013$': 51.08,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1837703',
#   'title': 'The Fifth Estate',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 26.0,
#   'domgross': 3.25,
#   'intgross': 6.15,
#   'code': '2013FAIL',
#   'budget_2013$': 26.0,
#   'domgross_2013$': 3.25,
#   'intgross_2013$': 6.15,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1343092',
#   'title': 'The Great Gatsby',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 190.0,
#   'domgross': 144.84,
#   'intgross': 351.04,
#   'code': '2013FAIL',
#   'budget_2013$': 190.0,
#   'domgross_2013$': 144.84,
#   'intgross_2013$': 351.04,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1951261',
#   'title': 'The Hangover part 3',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 103.0,
#   'domgross': 112.2,
#   'intgross': 362.0,
#   'code': '2013FAIL',
#   'budget_2013$': 103.0,
#   'domgross_2013$': 112.2,
#   'intgross_2013$': 362.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2404463',
#   'title': 'The Heat',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 43.0,
#   'domgross': 159.58,
#   'intgross': 230.78,
#   'code': '2013PASS',
#   'budget_2013$': 43.0,
#   'domgross_2013$': 159.58,
#   'intgross_2013$': 230.78,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1170358',
#   'title': 'The Hobbit: The Desolation of Smaug',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 250.0,
#   'domgross': 257.4,
#   'intgross': 937.4,
#   'code': '2013FAIL',
#   'budget_2013$': 250.0,
#   'domgross_2013$': 257.4,
#   'intgross_2013$': 937.4,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1517260',
#   'title': 'The Host',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 50.0,
#   'domgross': 26.62,
#   'intgross': 58.19,
#   'code': '2013FAIL',
#   'budget_2013$': 50.0,
#   'domgross_2013$': 26.62,
#   'intgross_2013$': 58.19,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1951264',
#   'title': 'The Hunger Games: Catching Fire',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 130.0,
#   'domgross': 424.09,
#   'intgross': 857.09,
#   'code': '2013PASS',
#   'budget_2013$': 130.0,
#   'domgross_2013$': 424.09,
#   'intgross_2013$': 857.09,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0790628',
#   'title': 'The Incredible Burt Wonderstone',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 32.0,
#   'domgross': 22.54,
#   'intgross': 24.26,
#   'code': '2013FAIL',
#   'budget_2013$': 32.0,
#   'domgross_2013$': 22.54,
#   'intgross_2013$': 24.26,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2234155',
#   'title': 'The Internship',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 58.0,
#   'domgross': 44.67,
#   'intgross': 93.67,
#   'code': '2013FAIL',
#   'budget_2013$': 58.0,
#   'domgross_2013$': 44.67,
#   'intgross_2013$': 93.67,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2034139',
#   'title': 'The Last Exorcism Part II',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 4.0,
#   'domgross': 15.18,
#   'intgross': 18.54,
#   'code': '2013PASS',
#   'budget_2013$': 4.0,
#   'domgross_2013$': 15.18,
#   'intgross_2013$': 18.54,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1210819',
#   'title': 'The Lone Ranger',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 275.0,
#   'domgross': 89.29,
#   'intgross': 259.99,
#   'code': '2013FAIL',
#   'budget_2013$': 275.0,
#   'domgross_2013$': 89.29,
#   'intgross_2013$': 259.99,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1538403',
#   'title': 'The Mortal Instruments: City of Bones',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 60.0,
#   'domgross': 31.17,
#   'intgross': 75.97,
#   'code': '2013PASS',
#   'budget_2013$': 60.0,
#   'domgross_2013$': 31.17,
#   'intgross_2013$': 75.97,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2184339',
#   'title': 'The Purge',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 3.0,
#   'domgross': 64.47,
#   'intgross': 91.1,
#   'code': '2013FAIL',
#   'budget_2013$': 3.0,
#   'domgross_2013$': 64.47,
#   'intgross_2013$': 91.1,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2017020',
#   'title': 'The Smurfs 2',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 110.0,
#   'domgross': 71.02,
#   'intgross': 348.55,
#   'code': '2013PASS',
#   'budget_2013$': 110.0,
#   'domgross_2013$': 71.02,
#   'intgross_2013$': 348.55,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1758795',
#   'title': 'The To Do List',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 1.5,
#   'domgross': 3.49,
#   'intgross': 3.49,
#   'code': '2013PASS',
#   'budget_2013$': 1.5,
#   'domgross_2013$': 3.49,
#   'intgross_2013$': 3.49,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1727388',
#   'title': 'The Way Way Back',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 5.0,
#   'domgross': 21.5,
#   'intgross': 26.16,
#   'code': '2013PASS',
#   'budget_2013$': 5.0,
#   'domgross_2013$': 21.5,
#   'intgross_2013$': 26.16,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0993846',
#   'title': 'The Wolf of Wall Street',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 100.0,
#   'domgross': 115.7,
#   'intgross': 365.7,
#   'code': '2013FAIL',
#   'budget_2013$': 100.0,
#   'domgross_2013$': 115.7,
#   'intgross_2013$': 365.7,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1430132',
#   'title': 'The Wolverine',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 115.0,
#   'domgross': 132.56,
#   'intgross': 416.46,
#   'code': '2013PASS',
#   'budget_2013$': 115.0,
#   'domgross_2013$': 132.56,
#   'intgross_2013$': 416.46,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1213663',
#   'title': 'The World&#39;s End',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 20.0,
#   'domgross': 26.0,
#   'intgross': 46.58,
#   'code': '2013FAIL',
#   'budget_2013$': 20.0,
#   'domgross_2013$': 26.0,
#   'intgross_2013$': 46.58,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1245492',
#   'title': 'This Is the End',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 32.0,
#   'domgross': 101.47,
#   'intgross': 126.29,
#   'code': '2013FAIL',
#   'budget_2013$': 32.0,
#   'domgross_2013$': 101.47,
#   'intgross_2013$': 126.29,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1981115',
#   'title': 'Thor: The Dark World',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 170.0,
#   'domgross': 204.67,
#   'intgross': 631.67,
#   'code': '2013FAIL',
#   'budget_2013$': 170.0,
#   'domgross_2013$': 204.67,
#   'intgross_2013$': 631.67,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1924429',
#   'title': 'Trance',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 16.0,
#   'domgross': 2.32,
#   'intgross': 22.59,
#   'code': '2013FAIL',
#   'budget_2013$': 16.0,
#   'domgross_2013$': 2.32,
#   'intgross_2013$': 22.59,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1860353',
#   'title': 'Turbo',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 135.0,
#   'domgross': 83.03,
#   'intgross': 283.83,
#   'code': '2013FAIL',
#   'budget_2013$': 135.0,
#   'domgross_2013$': 83.03,
#   'intgross_2013$': 283.83,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1588173',
#   'title': 'Warm Bodies',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 30.0,
#   'domgross': 66.38,
#   'intgross': 116.64,
#   'code': '2013FAIL',
#   'budget_2013$': 30.0,
#   'domgross_2013$': 66.38,
#   'intgross_2013$': 116.64,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1723121',
#   'title': 'We&#39;re the Millers',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 37.0,
#   'domgross': 150.39,
#   'intgross': 270.0,
#   'code': '2013PASS',
#   'budget_2013$': 37.0,
#   'domgross_2013$': 150.39,
#   'intgross_2013$': 270.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt2334879',
#   'title': 'White House Down',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 150.0,
#   'domgross': 73.1,
#   'intgross': 205.44,
#   'code': '2013FAIL',
#   'budget_2013$': 150.0,
#   'domgross_2013$': 73.1,
#   'intgross_2013$': 205.44,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt0816711',
#   'title': 'World War Z',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 190.0,
#   'domgross': 202.36,
#   'intgross': 539.56,
#   'code': '2013FAIL',
#   'budget_2013$': 190.0,
#   'domgross_2013$': 202.36,
#   'intgross_2013$': 539.56,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1611224',
#   'title': 'Abraham Lincoln: Vampire Hunter',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 67.5,
#   'domgross': 37.52,
#   'intgross': 115.12,
#   'code': '2012FAIL',
#   'budget_2013$': 68.49,
#   'domgross_2013$': 38.07,
#   'intgross_2013$': 116.8,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1591479',
#   'title': 'Act of Valor',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 12.0,
#   'domgross': 70.01,
#   'intgross': 82.5,
#   'code': '2012FAIL',
#   'budget_2013$': 12.18,
#   'domgross_2013$': 71.04,
#   'intgross_2013$': 83.7,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1602620',
#   'title': 'Amour',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 9.7,
#   'domgross': 6.74,
#   'intgross': 25.92,
#   'code': '2012FAIL',
#   'budget_2013$': 9.84,
#   'domgross_2013$': 6.84,
#   'intgross_2013$': 26.3,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1781769',
#   'title': 'Anna Karenina',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 49.0,
#   'domgross': 12.82,
#   'intgross': 70.74,
#   'code': '2012FAIL',
#   'budget_2013$': 49.72,
#   'domgross_2013$': 13.0,
#   'intgross_2013$': 71.77,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1024648',
#   'title': 'Argo',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 44.5,
#   'domgross': 136.03,
#   'intgross': 221.3,
#   'code': '2012PASS',
#   'budget_2013$': 45.15,
#   'domgross_2013$': 138.02,
#   'intgross_2013$': 224.54,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1440129',
#   'title': 'Battleship',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 209.0,
#   'domgross': 65.24,
#   'intgross': 304.14,
#   'code': '2012FAIL',
#   'budget_2013$': 212.06,
#   'domgross_2013$': 66.19,
#   'intgross_2013$': 308.59,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt2125435',
#   'title': 'Beasts of the Southern Wild',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 1.8,
#   'domgross': 12.8,
#   'intgross': 21.08,
#   'code': '2012FAIL',
#   'budget_2013$': 1.83,
#   'domgross_2013$': 12.98,
#   'intgross_2013$': 21.39,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1758575',
#   'title': 'Blue Like Jazz',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 1.2,
#   'domgross': 0.6,
#   'intgross': 0.6,
#   'code': '2012PASS',
#   'budget_2013$': 1.22,
#   'domgross_2013$': 0.6,
#   'intgross_2013$': 0.6,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1217209',
#   'title': 'Brave',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 185.0,
#   'domgross': 237.28,
#   'intgross': 554.61,
#   'code': '2012PASS',
#   'budget_2013$': 187.71,
#   'domgross_2013$': 240.76,
#   'intgross_2013$': 562.73,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1308729',
#   'title': 'Bullet to the Head',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 55.0,
#   'domgross': 9.49,
#   'intgross': 13.56,
#   'code': '2012FAIL',
#   'budget_2013$': 55.81,
#   'domgross_2013$': 9.63,
#   'intgross_2013$': 13.76,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1991245',
#   'title': 'Chernobyl Diaries',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 1.0,
#   'domgross': 18.12,
#   'intgross': 38.39,
#   'code': '2012FAIL',
#   'budget_2013$': 1.01,
#   'domgross_2013$': 18.38,
#   'intgross_2013$': 38.95,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1706593',
#   'title': 'Chronicle',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 12.0,
#   'domgross': 64.58,
#   'intgross': 127.08,
#   'code': '2012FAIL',
#   'budget_2013$': 12.18,
#   'domgross_2013$': 65.52,
#   'intgross_2013$': 128.94,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1371111',
#   'title': 'Cloud Atlas',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 102.0,
#   'domgross': 27.11,
#   'intgross': 126.02,
#   'code': '2012PASS',
#   'budget_2013$': 103.49,
#   'domgross_2013$': 27.51,
#   'intgross_2013$': 127.86,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1524137',
#   'title': 'Contraband',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 25.0,
#   'domgross': 66.53,
#   'intgross': 98.41,
#   'code': '2012PASS',
#   'budget_2013$': 25.37,
#   'domgross_2013$': 67.5,
#   'intgross_2013$': 99.85,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1853728',
#   'title': 'Django Unchained',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 100.0,
#   'domgross': 162.81,
#   'intgross': 425.37,
#   'code': '2012FAIL',
#   'budget_2013$': 101.46,
#   'domgross_2013$': 165.19,
#   'intgross_2013$': 431.6,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1907668',
#   'title': 'Flight',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 31.0,
#   'domgross': 93.77,
#   'intgross': 161.77,
#   'code': '2012FAIL',
#   'budget_2013$': 31.45,
#   'domgross_2013$': 95.15,
#   'intgross_2013$': 164.14,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1142977',
#   'title': 'Frankenweenie',
#   'test': 'nowomen-disagree',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 39.0,
#   'domgross': 35.29,
#   'intgross': 81.15,
#   'code': '2012FAIL',
#   'budget_2013$': 39.57,
#   'domgross_2013$': 35.8,
#   'intgross_2013$': 82.34,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt2243973',
#   'title': 'Hannibal',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 87.0,
#   'domgross': 165.09,
#   'intgross': 350.1,
#   'code': '2012PASS',
#   'budget_2013$': 88.27,
#   'domgross_2013$': 167.51,
#   'intgross_2013$': 355.23,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt0837562',
#   'title': 'Hotel Transylvania',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 85.0,
#   'domgross': 148.31,
#   'intgross': 359.22,
#   'code': '2012PASS',
#   'budget_2013$': 86.24,
#   'domgross_2013$': 150.48,
#   'intgross_2013$': 364.48,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt0790724',
#   'title': 'Jack Reacher',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 60.0,
#   'domgross': 80.07,
#   'intgross': 217.37,
#   'code': '2012FAIL',
#   'budget_2013$': 60.88,
#   'domgross_2013$': 81.24,
#   'intgross_2013$': 220.55,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt2106476',
#   'title': 'Jagten',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 3.45,
#   'domgross': 0.69,
#   'intgross': 0.69,
#   'code': '2012FAIL',
#   'budget_2013$': 3.5,
#   'domgross_2013$': 0.7,
#   'intgross_2013$': 0.7,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt0401729',
#   'title': 'John Carter',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 275.0,
#   'domgross': 73.06,
#   'intgross': 282.78,
#   'code': '2012PASS',
#   'budget_2013$': 279.03,
#   'domgross_2013$': 74.13,
#   'intgross_2013$': 286.92,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1764234',
#   'title': 'Killing Them Softly',
#   'test': 'nowomen',
#   'clean_test': 'nowomen',
#   'binary': 'FAIL',
#   'budget': 15.0,
#   'domgross': 14.95,
#   'intgross': 37.24,
#   'code': '2012FAIL',
#   'budget_2013$': 15.22,
#   'domgross_2013$': 15.16,
#   'intgross_2013$': 37.78,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1707386',
#   'title': 'Les Miserables',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 65.0,
#   'domgross': 148.81,
#   'intgross': 442.02,
#   'code': '2012PASS',
#   'budget_2013$': 65.95,
#   'domgross_2013$': 150.99,
#   'intgross_2013$': 448.49,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt0454876',
#   'title': 'Life of Pi',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 120.0,
#   'domgross': 124.99,
#   'intgross': 607.99,
#   'code': '2012FAIL',
#   'budget_2013$': 121.76,
#   'domgross_2013$': 126.82,
#   'intgross_2013$': 616.89,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt0443272',
#   'title': 'Lincoln',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 65.0,
#   'domgross': 182.21,
#   'intgross': 273.0,
#   'code': '2012PASS',
#   'budget_2013$': 65.95,
#   'domgross_2013$': 184.88,
#   'intgross_2013$': 277.0,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1277953',
#   'title': 'Madagascar 3: Europe&#39;s Most Wanted',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 145.0,
#   'domgross': 216.39,
#   'intgross': 746.92,
#   'code': '2012FAIL',
#   'budget_2013$': 147.12,
#   'domgross_2013$': 219.56,
#   'intgross_2013$': 757.86,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1409024',
#   'title': 'Men in Black III',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 215.0,
#   'domgross': 179.02,
#   'intgross': 624.82,
#   'code': '2012FAIL',
#   'budget_2013$': 218.15,
#   'domgross_2013$': 181.64,
#   'intgross_2013$': 633.97,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1667353',
#   'title': 'Mirror Mirror',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 85.0,
#   'domgross': 64.94,
#   'intgross': 168.61,
#   'code': '2012FAIL',
#   'budget_2013$': 86.24,
#   'domgross_2013$': 65.89,
#   'intgross_2013$': 171.08,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1748122',
#   'title': 'Moonrise Kingdom',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 16.0,
#   'domgross': 45.51,
#   'intgross': 64.01,
#   'code': '2012PASS',
#   'budget_2013$': 16.23,
#   'domgross_2013$': 46.18,
#   'intgross_2013$': 64.95,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt2094064',
#   'title': 'Much Ado About Nothing',
#   'test': 'dubious-disagree',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 8.0,
#   'domgross': 22.55,
#   'intgross': 22.55,
#   'code': '2012FAIL',
#   'budget_2013$': 8.12,
#   'domgross_2013$': 22.88,
#   'intgross_2013$': 22.88,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1598828',
#   'title': 'One for the Money',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 42.0,
#   'domgross': 26.41,
#   'intgross': 36.2,
#   'code': '2012PASS',
#   'budget_2013$': 42.61,
#   'domgross_2013$': 26.8,
#   'intgross_2013$': 36.73,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt2109184',
#   'title': 'Paranormal Activity 4',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 5.0,
#   'domgross': 53.9,
#   'intgross': 142.79,
#   'code': '2012PASS',
#   'budget_2013$': 5.07,
#   'domgross_2013$': 54.69,
#   'intgross_2013$': 144.88,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1623288',
#   'title': 'ParaNorman',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 60.0,
#   'domgross': 56.0,
#   'intgross': 108.16,
#   'code': '2012FAIL',
#   'budget_2013$': 60.88,
#   'domgross_2013$': 56.82,
#   'intgross_2013$': 109.74,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1047540',
#   'title': 'Parental Guidance',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 25.0,
#   'domgross': 77.27,
#   'intgross': 120.17,
#   'code': '2012PASS',
#   'budget_2013$': 25.37,
#   'domgross_2013$': 78.4,
#   'intgross_2013$': 121.93,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1716777',
#   'title': 'People Like Us',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 16.0,
#   'domgross': 12.43,
#   'intgross': 12.43,
#   'code': '2012PASS',
#   'budget_2013$': 16.23,
#   'domgross_2013$': 12.61,
#   'intgross_2013$': 12.61,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1981677',
#   'title': 'Pitch Perfect',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 17.0,
#   'domgross': 65.0,
#   'intgross': 115.33,
#   'code': '2012PASS',
#   'budget_2013$': 17.25,
#   'domgross_2013$': 65.95,
#   'intgross_2013$': 117.02,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1547234',
#   'title': 'Premium Rush',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 35.0,
#   'domgross': 20.28,
#   'intgross': 31.39,
#   'code': '2012PASS',
#   'budget_2013$': 35.51,
#   'domgross_2013$': 20.57,
#   'intgross_2013$': 31.85,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1234719',
#   'title': 'Red Dawn',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 65.0,
#   'domgross': 44.81,
#   'intgross': 48.16,
#   'code': '2012FAIL',
#   'budget_2013$': 65.95,
#   'domgross_2013$': 45.46,
#   'intgross_2013$': 48.87,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt0485985',
#   'title': 'Red Tails',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 58.0,
#   'domgross': 49.88,
#   'intgross': 50.37,
#   'code': '2012FAIL',
#   'budget_2013$': 58.85,
#   'domgross_2013$': 50.61,
#   'intgross_2013$': 51.1,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1446192',
#   'title': 'Rise of the Guardians',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 145.0,
#   'domgross': 103.41,
#   'intgross': 306.9,
#   'code': '2012FAIL',
#   'budget_2013$': 147.12,
#   'domgross_2013$': 104.93,
#   'intgross_2013$': 311.39,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1336608',
#   'title': 'Rock of Ages',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 70.0,
#   'domgross': 38.52,
#   'intgross': 50.12,
#   'code': '2012PASS',
#   'budget_2013$': 71.02,
#   'domgross_2013$': 39.08,
#   'intgross_2013$': 50.85,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2012,
#   'imdb': 'tt1656190',
#   'title': 'Safe',
# ...
#   'title': 'My Summer of Love',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 1.7,
#   'domgross': 1.0,
#   'intgross': 4.95,
#   'code': '2004PASS',
#   'budget_2013$': 2.1,
#   'domgross_2013$': 1.23,
#   'intgross_2013$': 6.11,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0374900',
#   'title': 'Napoleon Dynamite',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 0.4,
#   'domgross': 44.54,
#   'intgross': 46.12,
#   'code': '2004FAIL',
#   'budget_2013$': 0.49,
#   'domgross_2013$': 54.93,
#   'intgross_2013$': 56.88,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0363282',
#   'title': 'New York Minute',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 40.0,
#   'domgross': 14.02,
#   'intgross': 21.22,
#   'code': '2004FAIL',
#   'budget_2013$': 49.33,
#   'domgross_2013$': 17.29,
#   'intgross_2013$': 26.16,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0390384',
#   'title': 'Primer',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 0.01,
#   'domgross': 0.42,
#   'intgross': 0.57,
#   'code': '2004FAIL',
#   'budget_2013$': 0.01,
#   'domgross_2013$': 0.52,
#   'intgross_2013$': 0.7,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0350028',
#   'title': 'Raising Helen',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 50.0,
#   'domgross': 37.49,
#   'intgross': 43.34,
#   'code': '2004PASS',
#   'budget_2013$': 61.66,
#   'domgross_2013$': 46.23,
#   'intgross_2013$': 53.45,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0350258',
#   'title': 'Ray',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 40.0,
#   'domgross': 75.31,
#   'intgross': 124.82,
#   'code': '2004FAIL',
#   'budget_2013$': 49.33,
#   'domgross_2013$': 92.87,
#   'intgross_2013$': 153.93,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0318627',
#   'title': 'Resident Evil: Apocalypse',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 50.0,
#   'domgross': 50.74,
#   'intgross': 128.94,
#   'code': '2004PASS',
#   'budget_2013$': 61.66,
#   'domgross_2013$': 62.57,
#   'intgross_2013$': 159.01,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0332375',
#   'title': 'Saved!',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 5.0,
#   'domgross': 8.89,
#   'intgross': 10.23,
#   'code': '2004PASS',
#   'budget_2013$': 6.17,
#   'domgross_2013$': 10.96,
#   'intgross_2013$': 12.61,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0387564',
#   'title': 'Saw',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 1.2,
#   'domgross': 55.19,
#   'intgross': 103.1,
#   'code': '2004FAIL',
#   'budget_2013$': 1.48,
#   'domgross_2013$': 68.05,
#   'intgross_2013$': 127.14,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0363988',
#   'title': 'Secret Window',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 40.0,
#   'domgross': 47.96,
#   'intgross': 92.11,
#   'code': '2004FAIL',
#   'budget_2013$': 49.33,
#   'domgross_2013$': 59.14,
#   'intgross_2013$': 113.59,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0307453',
#   'title': 'Shark Tale',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 75.0,
#   'domgross': 161.41,
#   'intgross': 367.83,
#   'code': '2004FAIL',
#   'budget_2013$': 92.49,
#   'domgross_2013$': 199.05,
#   'intgross_2013$': 453.6,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0365748',
#   'title': 'Shaun of the Dead',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 5.0,
#   'domgross': 13.54,
#   'intgross': 30.33,
#   'code': '2004PASS',
#   'budget_2013$': 6.17,
#   'domgross_2013$': 16.7,
#   'intgross_2013$': 37.41,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0298148',
#   'title': 'Shrek 2',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 70.0,
#   'domgross': 441.23,
#   'intgross': 937.01,
#   'code': '2004PASS',
#   'budget_2013$': 86.32,
#   'domgross_2013$': 544.12,
#   'intgross_2013$': 1155.51,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0375063',
#   'title': 'Sideways',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 17.0,
#   'domgross': 71.5,
#   'intgross': 109.87,
#   'code': '2004PASS',
#   'budget_2013$': 20.96,
#   'domgross_2013$': 88.18,
#   'intgross_2013$': 135.5,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0346156',
#   'title': 'Sky Captain and the World of Tomorrow',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 70.0,
#   'domgross': 37.76,
#   'intgross': 49.73,
#   'code': '2004PASS',
#   'budget_2013$': 86.32,
#   'domgross_2013$': 46.57,
#   'intgross_2013$': 61.33,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0371246',
#   'title': 'Spanglish',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 75.0,
#   'domgross': 42.04,
#   'intgross': 54.34,
#   'code': '2004PASS',
#   'budget_2013$': 92.49,
#   'domgross_2013$': 51.85,
#   'intgross_2013$': 67.02,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0316654',
#   'title': 'Spider-Man 2',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 200.0,
#   'domgross': 373.52,
#   'intgross': 783.71,
#   'code': '2004FAIL',
#   'budget_2013$': 246.64,
#   'domgross_2013$': 460.63,
#   'intgross_2013$': 966.46,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0372588',
#   'title': 'Team America: World Police',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 20.0,
#   'domgross': 32.77,
#   'intgross': 50.27,
#   'code': '2004FAIL',
#   'budget_2013$': 24.66,
#   'domgross_2013$': 40.42,
#   'intgross_2013$': 62.0,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0338751',
#   'title': 'The Aviator',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 110.0,
#   'domgross': 102.61,
#   'intgross': 214.61,
#   'code': '2004FAIL',
#   'budget_2013$': 135.65,
#   'domgross_2013$': 126.54,
#   'intgross_2013$': 264.65,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0372183',
#   'title': 'The Bourne Supremacy',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 85.0,
#   'domgross': 176.09,
#   'intgross': 288.59,
#   'code': '2004FAIL',
#   'budget_2013$': 104.82,
#   'domgross_2013$': 217.15,
#   'intgross_2013$': 355.88,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0289879',
#   'title': 'The Butterfly Effect',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 13.0,
#   'domgross': 57.92,
#   'intgross': 96.05,
#   'code': '2004FAIL',
#   'budget_2013$': 16.03,
#   'domgross_2013$': 71.43,
#   'intgross_2013$': 118.44,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0296572',
#   'title': 'The Chronicles of Riddick',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 120.0,
#   'domgross': 57.71,
#   'intgross': 107.21,
#   'code': '2004FAIL',
#   'budget_2013$': 147.98,
#   'domgross_2013$': 71.17,
#   'intgross_2013$': 132.21,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0319262',
#   'title': 'The Day After Tomorrow',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 125.0,
#   'domgross': 186.74,
#   'intgross': 556.32,
#   'code': '2004PASS',
#   'budget_2013$': 154.15,
#   'domgross_2013$': 230.29,
#   'intgross_2013$': 686.05,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0391198',
#   'title': 'The Grudge',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 10.0,
#   'domgross': 110.36,
#   'intgross': 187.28,
#   'code': '2004PASS',
#   'budget_2013$': 12.33,
#   'domgross_2013$': 136.09,
#   'intgross_2013$': 230.95,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0317705',
#   'title': 'The Incredibles',
#   'test': 'ok-disagree',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 92.0,
#   'domgross': 261.44,
#   'intgross': 632.11,
#   'code': '2004PASS',
#   'budget_2013$': 113.45,
#   'domgross_2013$': 322.41,
#   'intgross_2013$': 779.51,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0362270',
#   'title': 'The Life Aquatic with Steve Zissou',
#   'test': 'men',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 50.0,
#   'domgross': 24.01,
#   'intgross': 34.81,
#   'code': '2004FAIL',
#   'budget_2013$': 61.66,
#   'domgross_2013$': 29.6,
#   'intgross_2013$': 42.92,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0332280',
#   'title': 'The Notebook',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 30.0,
#   'domgross': 81.0,
#   'intgross': 102.28,
#   'code': '2004FAIL',
#   'budget_2013$': 37.0,
#   'domgross_2013$': 99.89,
#   'intgross_2013$': 126.13,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0293508',
#   'title': 'The Phantom of the Opera',
#   'test': 'men-disagree',
#   'clean_test': 'men',
#   'binary': 'FAIL',
#   'budget': 55.0,
#   'domgross': 51.23,
#   'intgross': 158.23,
#   'code': '2004FAIL',
#   'budget_2013$': 67.83,
#   'domgross_2013$': 63.17,
#   'intgross_2013$': 195.12,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0338348',
#   'title': 'The Polar Express',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 170.0,
#   'domgross': 194.95,
#   'intgross': 319.05,
#   'code': '2004FAIL',
#   'budget_2013$': 209.64,
#   'domgross_2013$': 240.41,
#   'intgross_2013$': 393.45,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0368933',
#   'title': 'The Princess Diaries 2: Royal Engagement',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 45.0,
#   'domgross': 95.15,
#   'intgross': 122.07,
#   'code': '2004PASS',
#   'budget_2013$': 55.49,
#   'domgross_2013$': 117.34,
#   'intgross_2013$': 150.54,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0327162',
#   'title': 'The Stepford Wives',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 100.0,
#   'domgross': 59.48,
#   'intgross': 96.22,
#   'code': '2004PASS',
#   'budget_2013$': 123.32,
#   'domgross_2013$': 73.34,
#   'intgross_2013$': 118.66,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0362227',
#   'title': 'The Terminal',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 75.0,
#   'domgross': 77.07,
#   'intgross': 218.67,
#   'code': '2004FAIL',
#   'budget_2013$': 92.49,
#   'domgross_2013$': 95.05,
#   'intgross_2013$': 269.67,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0368447',
#   'title': 'The Village',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 71.68,
#   'domgross': 114.2,
#   'intgross': 257.64,
#   'code': '2004PASS',
#   'budget_2013$': 88.4,
#   'domgross_2013$': 140.83,
#   'intgross_2013$': 317.72,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0327247',
#   'title': 'The Whole Ten Yards',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 30.0,
#   'domgross': 16.32,
#   'intgross': 26.32,
#   'code': '2004FAIL',
#   'budget_2013$': 37.0,
#   'domgross_2013$': 20.13,
#   'intgross_2013$': 32.46,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0332452',
#   'title': 'Troy',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 150.0,
#   'domgross': 133.3,
#   'intgross': 484.16,
#   'code': '2004FAIL',
#   'budget_2013$': 184.98,
#   'domgross_2013$': 164.38,
#   'intgross_2013$': 597.06,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0338526',
#   'title': 'Van Helsing',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 170.0,
#   'domgross': 120.15,
#   'intgross': 300.15,
#   'code': '2004PASS',
#   'budget_2013$': 209.64,
#   'domgross_2013$': 148.17,
#   'intgross_2013$': 370.14,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0383694',
#   'title': 'Vera Drake',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 11.0,
#   'domgross': 3.75,
#   'intgross': 13.35,
#   'code': '2004PASS',
#   'budget_2013$': 13.57,
#   'domgross_2013$': 4.63,
#   'intgross_2013$': 16.47,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0381707',
#   'title': 'White Chicks',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 20.0,
#   'domgross': 69.15,
#   'intgross': 111.45,
#   'code': '2004PASS',
#   'budget_2013$': 24.66,
#   'domgross_2013$': 85.27,
#   'intgross_2013$': 137.44,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2004,
#   'imdb': 'tt0360201',
#   'title': 'Wimbledon',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 35.0,
#   'domgross': 16.86,
#   'intgross': 41.67,
#   'code': '2004PASS',
#   'budget_2013$': 43.16,
#   'domgross_2013$': 20.79,
#   'intgross_2013$': 51.38,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0322259',
#   'title': '2 Fast 2 Furious',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 76.0,
#   'domgross': 127.12,
#   'intgross': 236.22,
#   'code': '2003FAIL',
#   'budget_2013$': 96.22,
#   'domgross_2013$': 160.95,
#   'intgross_2013$': 299.08,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0315733',
#   'title': '21 grams',
#   'test': 'dubious',
#   'clean_test': 'dubious',
#   'binary': 'FAIL',
#   'budget': 20.0,
#   'domgross': 16.25,
#   'intgross': 59.67,
#   'code': '2003FAIL',
#   'budget_2013$': 25.32,
#   'domgross_2013$': 20.57,
#   'intgross_2013$': 75.54,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0319061',
#   'title': 'Big Fish',
#   'test': 'notalk-disagree',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 70.0,
#   'domgross': 66.43,
#   'intgross': 123.43,
#   'code': '2003FAIL',
#   'budget_2013$': 88.63,
#   'domgross_2013$': 84.11,
#   'intgross_2013$': 156.28,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0310778',
#   'title': 'Bon voyage',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 20.0,
#   'domgross': 2.35,
#   'intgross': 8.36,
#   'code': '2003PASS',
#   'budget_2013$': 25.32,
#   'domgross_2013$': 2.98,
#   'intgross_2013$': 10.59,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0315327',
#   'title': 'Bruce Almighty',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 81.0,
#   'domgross': 242.7,
#   'intgross': 483.47,
#   'code': '2003PASS',
#   'budget_2013$': 102.55,
#   'domgross_2013$': 307.29,
#   'intgross_2013$': 612.12,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0305357',
#   'title': 'Charlie&#39;s Angels: Full Throttle',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 120.0,
#   'domgross': 100.81,
#   'intgross': 227.2,
#   'code': '2003PASS',
#   'budget_2013$': 151.93,
#   'domgross_2013$': 127.64,
#   'intgross_2013$': 287.65,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0159365',
#   'title': 'Cold Mountain',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 80.0,
#   'domgross': 95.63,
#   'intgross': 161.63,
#   'code': '2003PASS',
#   'budget_2013$': 101.29,
#   'domgross_2013$': 121.08,
#   'intgross_2013$': 204.64,
#   'period code': 3.0,
#   'decade code': 2.0},
#  {'year': 2003,
#   'imdb': 'tt0306685',
#   'title': 'Cradle 2 the Grave',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 25.0,
#   'domgross': 34.66,
#   'intgross': 56.43,
#   'code': '2003FAIL',
#   'budget_2013$': 31.65,
#   'domgross_2013$': 43.88,
#   'intgross_2013$': 71.45,
#   'period code': 3.0,
#   'decade code': 2.0},
#  ...]

# %% [markdown]
# After writing the `remove_movies_missing_data` function, notice that we have reduced the number of movies down from 1794 to 1776 movies.

# %%
len(parsed_movies) # 1776
# Out:
# 1776

# %% [markdown]
# Also, we can see that no movies with a `domgross_2013` value of `nan` are included.

# %%
list(filter(lambda movie: math.isnan(movie['domgross_2013$']),parsed_movies)) # []
# Out:
# []

# %% [markdown]
# #### 2. Changing the scale of our data
#
# Currently, our data has some very large numbers:

# %%
movies[0]['budget']
# Out:
# 13000000

# %% [markdown]
# It takes some time to figure out the number above is 13 million.  It would be frustrating to count all of the zeros whenever we come across another set of movie budgets and revenues.
#
# To make things simpler, let's divide both our budget and revenue numbers for each movie by 1 million. It will make some of our future calculations easier to interpret. The attributes that we can scale down are `budget`, `budget_2013$`, `domgross`, `domgross_2013$`, `intgross`, and `intgross_2013$`.
#
# Write a function called `scale_down_movie` that can take an element from our movies list and return that same movie but with the `budget`, `budget_2013$`, `domgross`, `domgross_2013$`, `intgross`, and `intgross_2013$` numbers all divided by 1 million and rounded to two decimal places.

# %%
movies = parse_file('https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv')

parsed_movies = remove_movies_missing_data(movies) or []

def scale_down_movie(movie):
    movie['budget'] = round(movie['budget']/1000000, 2)
    movie['budget_2013$'] = round(movie['budget_2013$']/1000000,2)
    movie['domgross'] = round(movie['domgross']/1000000,2)
    movie['domgross_2013$'] = round(movie['domgross_2013$']/1000000,2)
    movie['intgross'] = round(movie['intgross']/1000000,2)
    movie['intgross_2013$'] = round(movie['intgross_2013$']/1000000,2)
    return movie

# %%
movies[0]
# Out:
# {'year': 2013,
#  'imdb': 'tt1711425',
#  'title': '21 &amp; Over',
#  'test': 'notalk',
#  'clean_test': 'notalk',
#  'binary': 'FAIL',
#  'budget': 13000000,
#  'domgross': 25682380.0,
#  'intgross': 42195766.0,
#  'code': '2013FAIL',
#  'budget_2013$': 13000000,
#  'domgross_2013$': 25682380.0,
#  'intgross_2013$': 42195766.0,
#  'period code': 1.0,
#  'decade code': 1.0}

# %%
scale_down_movie(parsed_movies[0])
# Out:
# {'year': 2013,
#  'imdb': 'tt1711425',
#  'title': '21 &amp; Over',
#  'test': 'notalk',
#  'clean_test': 'notalk',
#  'binary': 'FAIL',
#  'budget': 13.0,
#  'domgross': 25.68,
#  'intgross': 42.2,
#  'code': '2013FAIL',
#  'budget_2013$': 13.0,
#  'domgross_2013$': 25.68,
#  'intgross_2013$': 42.2,
#  'period code': 1.0,
#  'decade code': 1.0}

# %% [markdown]
# Ok, now that we have a function to scale down our movies, lets `map` through all of our `parsed_movies` to return a list of `scaled_movies`.

# %%
def scale_down_movies(movies):
    return list(map(lambda movie : scale_down_movie(movie), movies))

# %%
first_ten_movies = parsed_movies[0:10]
first_ten_scaled = scale_down_movies(first_ten_movies) or []
first_ten_scaled[-2:]
# [{'binary': 'PASS', 'budget': 13.0,
#   'budget_2013$': 13.0,
#   'clean_test': 'ok',
#   'code': '2013PASS',
#   'decade code': 1.0,
#   'domgross': 18.01,
#   'domgross_2013$': 18.01,
#   'imdb': 'tt1814621',
#   'intgross': 18.01,
#   'intgross_2013$': 18.01,
#   'period code': 1.0,
#   'test': 'ok',
#   'title': 'Admission',
#   'year': 2013},
#  {'binary': 'FAIL',
#   'budget': 130.0,
#   'budget_2013$': 130.0,
#   'clean_test': 'notalk',
#   'code': '2013FAIL',
#   'decade code': 1.0,
#   'domgross': 60.52,
#   'domgross_2013$': 60.52,
#   'imdb': 'tt1815862',
#   'intgross': 244.37,
#   'intgross_2013$': 244.37,
#   'period code': 1.0,
#   'test': 'notalk',
#   'title': 'After Earth',
#   'year': 2013}]
# Out:
# [{'year': 2013,
#   'imdb': 'tt1814621',
#   'title': 'Admission',
#   'test': 'ok',
#   'clean_test': 'ok',
#   'binary': 'PASS',
#   'budget': 13.0,
#   'domgross': 18.01,
#   'intgross': 18.01,
#   'code': '2013PASS',
#   'budget_2013$': 13.0,
#   'domgross_2013$': 18.01,
#   'intgross_2013$': 18.01,
#   'period code': 1.0,
#   'decade code': 1.0},
#  {'year': 2013,
#   'imdb': 'tt1815862',
#   'title': 'After Earth',
#   'test': 'notalk',
#   'clean_test': 'notalk',
#   'binary': 'FAIL',
#   'budget': 130.0,
#   'domgross': 60.52,
#   'intgross': 244.37,
#   'code': '2013FAIL',
#   'budget_2013$': 130.0,
#   'domgross_2013$': 60.52,
#   'intgross_2013$': 244.37,
#   'period code': 1.0,
#   'decade code': 1.0}]

# %%
scaled_movies = scale_down_movies(parsed_movies) or []

# %% [markdown]
# #### 3. Continue exploring the data
#
# Now let's plot our dataset using Plotly to see how much money a movie made domestically in 2013 dollars given a budget in 2013 dollars. Create a trace called `revenues_per_budgets_trace` that plots this data.
#
# > To do so, set `budget_2013$` as the $x$ values, and the `domgross_2013$` as the $y$ values. Set the text of the trace equal to a list of the movie titles, so that we can see which movie is associated with each point. All of the data should be coming from our `scaled_movies` variable.

# %%
movies = parse_file('https://raw.githubusercontent.com/fivethirtyeight/data/master/bechdel/movies.csv')

parsed_movies = remove_movies_missing_data(movies) or []

scaled_movies = scale_down_movies(parsed_movies) or []

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))
titles = list(map(lambda movie: movie['title'], scaled_movies))

# %% [markdown]
# We'll check the first ten values of the `budgets`, `domestic_revenues`, and `titles` lists, but your trace should have an element for each of the `scaled_movies` in the dataset.

# %%
budgets[0:10] # [13.0, 45.66, 20.0, 61.0, 40.0, 225.0, 92.0, 12.0, 13.0, 130.0]
# Out:
# [13.0, 45.66, 20.0, 61.0, 40.0, 225.0, 92.0, 12.0, 13.0, 130.0]

# %%
domestic_revenues[0:10] # [25.68, 13.61, 53.11, 75.61, 95.02, 38.36, 67.35, 15.32, 18.01, 60.52]
# Out:
# [25.68, 13.61, 53.11, 75.61, 95.02, 38.36, 67.35, 15.32, 18.01, 60.52]

# %%
titles[0:10] 
# ['21 &amp; Over',  'Dredd 3D', '12 Years a Slave', '2 Guns', '42', '47 Ronin',  'A Good Day to Die Hard',
# 'About Time',  'Admission',  'After Earth']
# Out:
# ['21 &amp; Over',
#  'Dredd 3D',
#  '12 Years a Slave',
#  '2 Guns',
#  '42',
#  '47 Ronin',
#  'A Good Day to Die Hard',
#  'About Time',
#  'Admission',
#  'After Earth']

# %% [markdown]
# Once we have lists of these values, we are ready to create a trace. The following code creates a trace with the x values set as the `budgets`, the y values set as the `domestic_revenues`, and the text set as each of the movie `titles`.

# %%
from graph import trace_values
revenues_per_budgets_trace = trace_values(budgets, domestic_revenues, text = titles)

# %% [markdown]
# > Once we have written the above code, we'll be ready to plot this data. Press shift + enter on the code below and you should see all movies in a graph.

# %%
from graph import plot
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

plot([revenues_per_budgets_trace])
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="d3dd901b-b423-4ae4-bb93-6d90ca1e2e29" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d3dd901b-b423-4ae4-bb93-6d90ca1e2e29", [{"mode": "markers", "name": "data", "text": ["21 &amp; Over", "Dredd 3D", "12 Years a Slave", "2 Guns", "42", "47 Ronin", "A Good Day to Die Hard", "About Time", "Admission", "After Earth", "American Hustle", "August: Osage County", "Beautiful Creatures", "Blue Jasmine", "Captain Phillips", "Carrie", "Cloudy with a Chance of Meatballs 2", "Despicable Me 2", "Don Jon", "Elysium", "Ender&#39;s Game", "Epic", "Escape from Planet Earth", "Escape Plan", "Evil Dead", "Fast and Furious 6", "Frozen", "G.I. Joe: Retaliation", "Gangster Squad", "Gloria", "Gravity", "Grown Ups 2", "Hansel &amp; Gretel: Witch Hunters", "Her", "Identity Thief", "Insidious: Chapter 2", "Iron Man 3", "Jack the Giant Slayer", "Kick-Ass 2", "Last Vegas", "Lee Daniels&#39; The Butler", "Machete Kills", "Mama", "Man of Steel", "Nebraska", "Now You See Me", "Oblivion", "Olympus Has Fallen", "Oz the Great and Powerful", "Pacific Rim", "Pain &amp; Gain", "Parker", "Peeples", "Percy Jackson: Sea of Monsters", "Prisoners", "R.I.P.D.", "Red 2", "Riddick", "Runner Runner", "Rush", "Safe Haven", "Saving Mr. Banks", "Side Effects", "Star Trek Into Darkness", "Texas Chainsaw 3D", "The Big Wedding", "The Book Thief", "The Call", "The Conjuring", "The Counselor", "The Croods", "The Family", "The Fifth Estate", "The Great Gatsby", "The Hangover part 3", "The Heat", "The Hobbit: The Desolation of Smaug", "The Host", "The Hunger Games: Catching Fire", "The Incredible Burt Wonderstone", "The Internship", "The Last Exorcism Part II", "The Lone Ranger", "The Mortal Instruments: City of Bones", "The Purge", "The Smurfs 2", "The To Do List", "The Way Way Back", "The Wolf of Wall Street", "The Wolverine", "The World&#39;s End", "This Is the End", "Thor: The Dark World", "Trance", "Turbo", "Warm Bodies", "We&#39;re the Millers", "White House Down", "World War Z", "Abraham Lincoln: Vampire Hunter", "Act of Valor", "Amour", "Anna Karenina", "Argo", "Battleship", "Beasts of the Southern Wild", "Blue Like Jazz", "Brave", "Bullet to the Head", "Chernobyl Diaries", "Chronicle", "Cloud Atlas", "Contraband", "Django Unchained", "Flight", "Frankenweenie", "Hannibal", "Hotel Transylvania", "Jack Reacher", "Jagten", "John Carter", "Killing Them Softly", "Les Miserables", "Life of Pi", "Lincoln", "Madagascar 3: Europe&#39;s Most Wanted", "Men in Black III", "Mirror Mirror", "Moonrise Kingdom", "Much Ado About Nothing", "One for the Money", "Paranormal Activity 4", "ParaNorman", "Parental Guidance", "People Like Us", "Pitch Perfect", "Premium Rush", "Red Dawn", "Red Tails", "Rise of the Guardians", "Rock of Ages", "Safe", "Safety Not Guaranteed", "Seven Psychopaths", "Silent Hill: Revelation 3D", "Silver Linings Playbook", "Sinister", "Skyfall", "Snow White and the Huntsman", "Sparkle", "Spring Breakers", "Step Up Revolution", "Supporting Characters", "Ted", "That&#39;s My Boy", "The Amazing Spider-Man", "The Avengers", "The Dark Knight Rises", "The Devil Inside", "The Dictator", "The Expendables 2", "The Grey", "The Hobbit: An Unexpected Journey", "The Hunger Games", "The Impossible", "The Man with the Iron Fists", "The Master", "The Pirates! Band of Misfits", "The Place Beyond the Pines", "The Twilight Saga: Breaking Dawn - Part 2", "The Vow", "The Watch", "The Woman in Black", "The Words", "Think Like a Man", "To Rome With Love", "Total Recall", "Underworld: Awakening", "Wanderlust", "What to Expect When You&#39;re Expecting", "Won&#39;t Back Down", "Wrath of the Titans", "Wreck-It Ralph", "Zero Dark Thirty", "30 Minutes or Less", "50/50", "A Dangerous Method", "A Very Harold &amp; Kumar 3D Christmas", "Another Earth", "Apollo 18", "Arthur Christmas", "Attack the Block", "Bad ...

# %% [markdown]
# Look at that one datapoint that earned well over 1.5 billion dollars.  What movie is that?

# %% [markdown]
# Write a function called `highest_domestic_gross` that finds the highest grossing movie given a list of movies.

# %%
def highest_domestic_gross(movies):
    return sorted(movies, key=lambda movie: movie['domgross_2013$'])[-1]

# %%
max_movie = highest_domestic_gross(scaled_movies) or {'title': 'some non movie'}
max_movie['title'] # 'Star Wars'
# Out:
# 'Star Wars'

# %% [markdown]
# Huh, well we should've known.  Now let's zoom in on our dataset so that our plot no longer expands for just a few of the outliers. We will set the x-axis of our plot to go from zero to 300 million dollars, and the y-axis of our plot to go from zero to one billion dollars.

# %%
from graph import build_layout
revenues_per_budgets_trace = trace_values(budgets, domestic_revenues, text = titles)
revenues_layout = build_layout(x_range = [0, 300], y_range = [0, 1000])
plot([revenues_per_budgets_trace], revenues_layout)
# Out:
# <div id="aadbc66c-cf90-4201-bac2-891ef8473621" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("aadbc66c-cf90-4201-bac2-891ef8473621", [{"mode": "markers", "name": "data", "text": ["21 &amp; Over", "Dredd 3D", "12 Years a Slave", "2 Guns", "42", "47 Ronin", "A Good Day to Die Hard", "About Time", "Admission", "After Earth", "American Hustle", "August: Osage County", "Beautiful Creatures", "Blue Jasmine", "Captain Phillips", "Carrie", "Cloudy with a Chance of Meatballs 2", "Despicable Me 2", "Don Jon", "Elysium", "Ender&#39;s Game", "Epic", "Escape from Planet Earth", "Escape Plan", "Evil Dead", "Fast and Furious 6", "Frozen", "G.I. Joe: Retaliation", "Gangster Squad", "Gloria", "Gravity", "Grown Ups 2", "Hansel &amp; Gretel: Witch Hunters", "Her", "Identity Thief", "Insidious: Chapter 2", "Iron Man 3", "Jack the Giant Slayer", "Kick-Ass 2", "Last Vegas", "Lee Daniels&#39; The Butler", "Machete Kills", "Mama", "Man of Steel", "Nebraska", "Now You See Me", "Oblivion", "Olympus Has Fallen", "Oz the Great and Powerful", "Pacific Rim", "Pain &amp; Gain", "Parker", "Peeples", "Percy Jackson: Sea of Monsters", "Prisoners", "R.I.P.D.", "Red 2", "Riddick", "Runner Runner", "Rush", "Safe Haven", "Saving Mr. Banks", "Side Effects", "Star Trek Into Darkness", "Texas Chainsaw 3D", "The Big Wedding", "The Book Thief", "The Call", "The Conjuring", "The Counselor", "The Croods", "The Family", "The Fifth Estate", "The Great Gatsby", "The Hangover part 3", "The Heat", "The Hobbit: The Desolation of Smaug", "The Host", "The Hunger Games: Catching Fire", "The Incredible Burt Wonderstone", "The Internship", "The Last Exorcism Part II", "The Lone Ranger", "The Mortal Instruments: City of Bones", "The Purge", "The Smurfs 2", "The To Do List", "The Way Way Back", "The Wolf of Wall Street", "The Wolverine", "The World&#39;s End", "This Is the End", "Thor: The Dark World", "Trance", "Turbo", "Warm Bodies", "We&#39;re the Millers", "White House Down", "World War Z", "Abraham Lincoln: Vampire Hunter", "Act of Valor", "Amour", "Anna Karenina", "Argo", "Battleship", "Beasts of the Southern Wild", "Blue Like Jazz", "Brave", "Bullet to the Head", "Chernobyl Diaries", "Chronicle", "Cloud Atlas", "Contraband", "Django Unchained", "Flight", "Frankenweenie", "Hannibal", "Hotel Transylvania", "Jack Reacher", "Jagten", "John Carter", "Killing Them Softly", "Les Miserables", "Life of Pi", "Lincoln", "Madagascar 3: Europe&#39;s Most Wanted", "Men in Black III", "Mirror Mirror", "Moonrise Kingdom", "Much Ado About Nothing", "One for the Money", "Paranormal Activity 4", "ParaNorman", "Parental Guidance", "People Like Us", "Pitch Perfect", "Premium Rush", "Red Dawn", "Red Tails", "Rise of the Guardians", "Rock of Ages", "Safe", "Safety Not Guaranteed", "Seven Psychopaths", "Silent Hill: Revelation 3D", "Silver Linings Playbook", "Sinister", "Skyfall", "Snow White and the Huntsman", "Sparkle", "Spring Breakers", "Step Up Revolution", "Supporting Characters", "Ted", "That&#39;s My Boy", "The Amazing Spider-Man", "The Avengers", "The Dark Knight Rises", "The Devil Inside", "The Dictator", "The Expendables 2", "The Grey", "The Hobbit: An Unexpected Journey", "The Hunger Games", "The Impossible", "The Man with the Iron Fists", "The Master", "The Pirates! Band of Misfits", "The Place Beyond the Pines", "The Twilight Saga: Breaking Dawn - Part 2", "The Vow", "The Watch", "The Woman in Black", "The Words", "Think Like a Man", "To Rome With Love", "Total Recall", "Underworld: Awakening", "Wanderlust", "What to Expect When You&#39;re Expecting", "Won&#39;t Back Down", "Wrath of the Titans", "Wreck-It Ralph", "Zero Dark Thirty", "30 Minutes or Less", "50/50", "A Dangerous Method", "A Very Harold &amp; Kumar 3D Christmas", "Another Earth", "Apollo 18", "Arthur Christmas", "Attack the Block", "Bad ...

# %% [markdown]
# Ok, well at least we have a closer look at our data.  We still see Titanic up in the top right corner.

# %% [markdown]
# ### Building our models

# %% [markdown]
# Ok, now that we have collected and explored this data, our company hired an outside consultant to create a model that predicts revenue for us. The consultant provided us with the following:
#
# $$R(x) = 1.5*budget + 10$$
#
# * where $x$ is a movie's budget in 2013 dollars, and $R(x)$ is the expected revenue in 2013 dollars.
#
# Write a function called `outside_consultant_predicted_revenue` that, provided a budget, returns the expected revenue according to the outside consultant's formula.

# %%
def outside_consultant_predicted_revenue(budget):
    return 1.5*budget + 10

# %% [markdown]
# Let's plot the consultant estimated revenue to see visually if his estimates line up.  We will call this trace `external consultant estimate`.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))
titles = list(map(lambda movie: movie['title'], scaled_movies))

consultant_estimated_revenues = list(map(lambda budget: outside_consultant_predicted_revenue(budget),budgets))
consultant_estimated_revenues_trace = trace_values(budgets, consultant_estimated_revenues, mode='lines', name = 'external consultant estimate')

# %%
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

from graph import trace_values, m_b_trace, plot

plot([revenues_per_budgets_trace, consultant_estimated_revenues_trace], revenues_layout)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="cf773970-efeb-4c9a-9a1e-519d193c3303" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cf773970-efeb-4c9a-9a1e-519d193c3303", [{"mode": "markers", "name": "data", "text": ["21 &amp; Over", "Dredd 3D", "12 Years a Slave", "2 Guns", "42", "47 Ronin", "A Good Day to Die Hard", "About Time", "Admission", "After Earth", "American Hustle", "August: Osage County", "Beautiful Creatures", "Blue Jasmine", "Captain Phillips", "Carrie", "Cloudy with a Chance of Meatballs 2", "Despicable Me 2", "Don Jon", "Elysium", "Ender&#39;s Game", "Epic", "Escape from Planet Earth", "Escape Plan", "Evil Dead", "Fast and Furious 6", "Frozen", "G.I. Joe: Retaliation", "Gangster Squad", "Gloria", "Gravity", "Grown Ups 2", "Hansel &amp; Gretel: Witch Hunters", "Her", "Identity Thief", "Insidious: Chapter 2", "Iron Man 3", "Jack the Giant Slayer", "Kick-Ass 2", "Last Vegas", "Lee Daniels&#39; The Butler", "Machete Kills", "Mama", "Man of Steel", "Nebraska", "Now You See Me", "Oblivion", "Olympus Has Fallen", "Oz the Great and Powerful", "Pacific Rim", "Pain &amp; Gain", "Parker", "Peeples", "Percy Jackson: Sea of Monsters", "Prisoners", "R.I.P.D.", "Red 2", "Riddick", "Runner Runner", "Rush", "Safe Haven", "Saving Mr. Banks", "Side Effects", "Star Trek Into Darkness", "Texas Chainsaw 3D", "The Big Wedding", "The Book Thief", "The Call", "The Conjuring", "The Counselor", "The Croods", "The Family", "The Fifth Estate", "The Great Gatsby", "The Hangover part 3", "The Heat", "The Hobbit: The Desolation of Smaug", "The Host", "The Hunger Games: Catching Fire", "The Incredible Burt Wonderstone", "The Internship", "The Last Exorcism Part II", "The Lone Ranger", "The Mortal Instruments: City of Bones", "The Purge", "The Smurfs 2", "The To Do List", "The Way Way Back", "The Wolf of Wall Street", "The Wolverine", "The World&#39;s End", "This Is the End", "Thor: The Dark World", "Trance", "Turbo", "Warm Bodies", "We&#39;re the Millers", "White House Down", "World War Z", "Abraham Lincoln: Vampire Hunter", "Act of Valor", "Amour", "Anna Karenina", "Argo", "Battleship", "Beasts of the Southern Wild", "Blue Like Jazz", "Brave", "Bullet to the Head", "Chernobyl Diaries", "Chronicle", "Cloud Atlas", "Contraband", "Django Unchained", "Flight", "Frankenweenie", "Hannibal", "Hotel Transylvania", "Jack Reacher", "Jagten", "John Carter", "Killing Them Softly", "Les Miserables", "Life of Pi", "Lincoln", "Madagascar 3: Europe&#39;s Most Wanted", "Men in Black III", "Mirror Mirror", "Moonrise Kingdom", "Much Ado About Nothing", "One for the Money", "Paranormal Activity 4", "ParaNorman", "Parental Guidance", "People Like Us", "Pitch Perfect", "Premium Rush", "Red Dawn", "Red Tails", "Rise of the Guardians", "Rock of Ages", "Safe", "Safety Not Guaranteed", "Seven Psychopaths", "Silent Hill: Revelation 3D", "Silver Linings Playbook", "Sinister", "Skyfall", "Snow White and the Huntsman", "Sparkle", "Spring Breakers", "Step Up Revolution", "Supporting Characters", "Ted", "That&#39;s My Boy", "The Amazing Spider-Man", "The Avengers", "The Dark Knight Rises", "The Devil Inside", "The Dictator", "The Expendables 2", "The Grey", "The Hobbit: An Unexpected Journey", "The Hunger Games", "The Impossible", "The Man with the Iron Fists", "The Master", "The Pirates! Band of Misfits", "The Place Beyond the Pines", "The Twilight Saga: Breaking Dawn - Part 2", "The Vow", "The Watch", "The Woman in Black", "The Words", "Think Like a Man", "To Rome With Love", "Total Recall", "Underworld: Awakening", "Wanderlust", "What to Expect When You&#39;re Expecting", "Won&#39;t Back Down", "Wrath of the Titans", "Wreck-It Ralph", "Zero Dark Thirty", "30 Minutes or Less", "50/50", "A Dangerous Method", "A Very Harold &amp; Kumar 3D Christmas", "Another Earth", "Apollo 18", "Arthur Christmas", "Attack the Block", "Bad ...

# %% [markdown]
# Overall, the model doesn't look too bad.  However, we can calculate the RSS to quantify how accurate his model really is.
#
# Let's write a method called `error_for_consultant_model` which takes in a budget of a movie in our dataset, and returns the difference between the movie's gross domestic revenue in 2013 dollars, and the prediction from the consultant's model.

# %%
#return different between domgross_2013 and prediction 
def error_for_consultant_model(movie):
    return movie['domgross_2013$'] - outside_consultant_predicted_revenue(movie['budget'])

# %%
american_hustle = {'binary': 'PASS', 'budget': 40.0, 'budget_2013$': 40.0, 'clean_test': 'ok',
         'code': '2013PASS', 'decade code': 1.0, 'domgross': 148.43, 'domgross_2013$': 148.43, 'imdb': 'tt1800241',
         'intgross': 249.48, 'intgross_2013$': 249.48, 'period code': 1.0, 'test': 'ok-disagree',
         'title': 'American Hustle', 'year': 2013}
error_for_consultant_model(american_hustle) # 78.43
# Out:
# 78.43

# %% [markdown]
# Once haven written a formula that calculates the error for the consultant's model provided a budget, we can write a method that calculates the RSS for the consultant's model.  When we move onto compare our consultant's model with others, we'll then have a metric for comparison.

# %%
from error import residual_sum_squares

def rss_consultant(movies):
    x_values = list(map(lambda movie : movie['budget'], movies))
    y_values = list(map(lambda movie : movie['domgross_2013$'], movies))
    return residual_sum_squares(x_values, y_values, 1.5, 10)

# %%
x_values = list(map(lambda movie : movie['budget'], movies))
x_values
# Out:
# [13.0,
#  45.0,
#  20.0,
#  61.0,
#  40.0,
#  225.0,
#  92.0,
#  12.0,
#  13.0,
#  130.0,
#  40.0,
#  25.0,
#  50.0,
#  18.0,
#  55.0,
#  30.0,
#  78.0,
#  76.0,
#  5.5,
#  120.0,
#  110.0,
#  100.0,
#  40.0,
#  70.0,
#  17.0,
#  160.0,
#  150.0,
#  140.0,
#  60.0,
#  30.0,
#  110.0,
#  80.0,
#  50.0,
#  23.0,
#  35.0,
#  5.0,
#  200.0,
#  195.0,
#  28.0,
#  28.0,
#  30.0,
#  2.0,
#  15.0,
#  225.0,
#  12.0,
#  75.0,
#  120.0,
#  70.0,
#  200.0,
#  190.0,
#  26.0,
#  35.0,
#  15.0,
#  90.0,
#  46.0,
#  130.0,
#  84.0,
#  38.0,
#  30.0,
#  38.0,
#  28.0,
#  35.0,
#  30.0,
#  190.0,
#  20.0,
#  32.5,
#  19.0,
#  13.0,
#  20.0,
#  25.0,
#  135.0,
#  30.0,
#  26.0,
#  19200000,
#  190.0,
#  103.0,
#  43.0,
#  250.0,
#  50.0,
#  130.0,
#  32.0,
#  58.0,
#  4.0,
#  275.0,
#  60.0,
#  3.0,
#  110.0,
#  1.5,
#  5.0,
#  100.0,
#  115.0,
#  20.0,
#  32.0,
#  170.0,
#  16.0,
#  135.0,
#  30.0,
#  37.0,
#  150.0,
#  190.0,
#  67.5,
#  12.0,
#  9.7,
#  49.0,
#  44.5,
#  209.0,
#  1.8,
#  1.2,
#  185.0,
#  55.0,
#  1.0,
#  12.0,
#  102.0,
#  25.0,
#  100.0,
#  31.0,
#  39.0,
#  87.0,
#  85.0,
#  60.0,
#  3.45,
#  275.0,
#  15.0,
#  65.0,
#  120.0,
#  65.0,
#  145.0,
#  215.0,
#  85.0,
#  16.0,
#  8.0,
#  42.0,
#  5.0,
#  60.0,
#  25.0,
#  16.0,
#  17.0,
#  35.0,
#  65.0,
#  58.0,
#  145.0,
#  70.0,
#  33.0,
#  0.75,
#  13.5,
#  20.0,
#  21.0,
#  3.0,
#  200.0,
#  170.0,
#  10.0,
#  5.0,
#  33.0,
#  0.06,
#  50.0,
#  67.5,
#  220.0,
#  60.0,
#  275.0,
#  1.0,
#  65.0,
#  100.0,
#  25.0,
#  250.0,
#  80.0,
#  40.0,
#  15.0,
#  37.5,
#  55.0,
#  15.0,
#  136.2,
#  8.74,
#  55.0,
#  15.0,
#  6.0,
#  12.0,
#  21.5,
#  125.0,
#  70.0,
#  32.5,
#  37.5,
#  19.0,
#  150.0,
#  165.0,
#  52.5,
#  28.0,
#  8.0,
#  20.0,
#  4000000,
#  20.0,
#  0.17,
#  5.0,
#  85.0,
#  13.0,
#  19.0,
#  70.0,
#  17.0,
#  4.5,
#  32.5,
#  140.0,
#  200.0,
#  0.9,
#  40.0,
#  20.0,
#  60.0,
#  10.0,
#  163.0,
#  10000000,
#  18.0,
#  37.0,
#  50.0,
#  15.0,
#  125.0,
#  40.0,
#  24.0,
#  30.0,
#  200.0,
#  36.0,
#  30.0,
#  125.0,
#  23.0,
#  7.0,
#  1.8,
#  3.0,
#  63.0,
#  35.0,
#  180.0,
#  50.0,
#  75.0,
#  35.0,
#  5.5,
#  100.0,
#  45.0,
#  7.0,
#  80.0,
#  0.8,
#  70.0,
#  150.0,
#  5.5,
#  0.25,
#  27.0,
#  14.0,
#  3.4,
#  150.0,
#  1.0,
#  9.4,
#  30.0,
#  145.0,
#  50.0,
#  55.0,
#  26.0,
#  25.0,
#  1.0,
#  5.0,
#  5.0,
#  40.0,
#  250.0,
#  60.0,
#  130.0,
#  135.0,
#  110.0,
#  42.0,
#  4.0,
#  8.0,
#  90.0,
#  93.0,
#  6.5,
#  6.0,
#  18.0,
#  32.0,
#  25.0,
#  75.0,
#  50.0,
#  4.75,
#  50.2,
#  130.0,
#  16.0,
#  10.0,
#  30.0,
#  34.8,
#  3.0,
#  1.0,
#  90.0,
#  110.0,
#  6.0,
#  25.0,
#  14.0,
#  40.0,
#  42.5,
#  45.0,
#  37.0,
#  16.0,
#  110.0,
#  90.0,
#  35.0,
#  127.5,
#  150.0,
#  21.0,
#  85.0,
#  195.0,
#  70.0,
#  25.0,
#  50.0,
#  0.19,
#  20.0,
#  30.0,
#  160.0,
#  12.0,
#  0.12,
#  18.0,
#  200.0,
#  4.2,
#  8.0,
#  30.0,
#  3.2,
#  35.0,
#  13.0,
#  1.0,
#  55.0,
#  12.5,
#  15.0,
#  44.0,
#  125.0,
#  12.5,
#  37.0,
#  15.0,
#  7.0,
#  55.0,
#  25.0,
#  69.0,
#  10.0,
#  15.0,
#  69.0,
#  25.0,
#  65.0,
#  20.0,
#  8.0,
#  60.0,
#  60.0,
#  5.0,
#  50.0,
#  12.0,
#  21.0,
#  150.0,
#  40.0,
#  32.0,
#  100.0,
#  75.0,
#  9.9,
#  125.0,
#  36.0,
#  165.0,
#  10.0,
#  160.0,
#  1.5,
#  170.0,
#  8.0,
#  28.0,
#  117.0,
#  26.0,
#  20.0,
#  30.0,
#  30.0,
#  12.5,
#  8.0,
#  2.0,
#  130.0,
#  0.5,
#  40.0,
#  35.0,
#  15.0,
#  3.0,
#  95.0,
#  3.0,
#  40.0,
#  200.0,
#  5.0,
#  15.0,
#  60.0,
#  16.0,
#  32.0,
#  210.0,
#  130.0,
#  85.0,
#  35.0,
#  95.0,
#  165.0,
#  80.0,
#  10.0,
#  7.0,
#  1.9,
#  2.5,
#  32.0,
#  260.0,
#  110.0,
#  35.0,
#  155.0,
#  25.0,
#  19.0,
#  20.0,
#  82.0,
#  11.0,
#  45.0,
#  16.5,
#  40.0,
#  4.0,
#  13.0,
#  15.0,
#  150.0,
#  1.8,
#  25.0,
#  30.0,
#  100.0,
#  9.5,
#  40.0,
#  160.0,
#  28.0,
#  19.0,
#  20.0,
#  100.0,
#  37.0,
#  68.0,
#  150.0,
#  0.05,
#  200.0,
#  200.0,
#  35.0,
#  5.0,
#  95.0,
#  52.0,
#  70.0,
#  10.0,
#  8.0,
#  2.0,
#  13000000,
#  80.0,
#  20.0,
#  15.0,
#  7.5,
#  40.0,
#  200.0,
#  30.0,
#  14.0,
#  7.0,
#  7.0,
#  3.2,
#  9.8,
#  70.0,
#  1.0,
#  15.0,
#  7.5,
#  150.0,
#  20.0,
#  65.0,
#  425.0,
#  21.0,
#  42.0,
#  30.0,
#  8.5,
#  17.0,
#  26.0,
#  20.0,
#  27.0,
#  13.0,
#  100.0,
#  23.0,
#  60.0,
#  20.0,
#  0.8,
#  30.0,
#  30.0,
#  16.0,
#  20.0,
#  40.0,
#  85.0,
#  20.0,
#  3.0,
#  17.0,
#  72.5,
#  150.0,
#  175.0,
#  50.0,
#  7.0,
#  7.3,
#  250.0,
#  40.0,
#  18000000,
#  13.0,
#  40.0,
#  90.0,
#  70.0,
#  49.0,
#  85.0,
#  16.0,
#  40.0,
#  50.0,
#  53.0,
#  4.5,
#  42.0,
#  175.0,
#  5.0,
#  7.0,
#  14.0,
#  27.5,
#  80.0,
#  50.0,
#  1.9,
#  12.0,
#  4.3,
#  40.0,
#  6.6,
#  60.0,
#  10.0,
#  102.5,
#  38.0,
#  90.0,
#  30.0,
#  140.0,
#  60.0,
#  80.0,
#  200.0,
#  35.0,
#  50.0,
#  8.0,
#  25.0,
#  8.3,
#  40.0,
#  10.0,
#  90.0,
#  1.3,
#  10.0,
#  35.0,
#  30.0,
#  22.0,
#  18.5,
#  18.0,
#  95.0,
#  24.0,
#  6.5,
#  105.0,
#  40.0,
#  25.0,
#  8.0,
#  60.0,
#  110.0,
#  39.0,
#  38.0,
#  16.0,
#  35.0,
#  210.0,
#  175.0,
#  30.0,
#  9000000,
#  138.0,
#  15.0,
#  100.0,
#  15.0,
#  35.0,
#  150.0,
#  200000,
#  18.0,
#  23.6,
#  35.0,
#  20.0,
#  130.0,
#  30.0,
#  20.0,
#  80.0,
#  25.0,
#  150.0,
#  37.0,
#  55.0,
#  58.0,
#  38.0,
#  25.0,
#  18000000,
#  65.0,
#  50.0,
#  7.0,
#  33.0,
#  20.0,
#  80.0,
#  14.0,
#  0.5,
#  25.0,
#  30.0,
#  80.0,
#  29.0,
#  1.0,
#  34.0,
#  20.0,
#  25.0,
#  9.0,
#  150.0,
#  82.5,
#  11.0,
#  30.0,
#  15.0,
#  185.0,
#  60.0,
#  186.0,
#  45.0,
#  82.5,
#  130.0,
#  4.5,
#  40.0,
#  35.0,
#  60.0,
#  20.0,
#  45.0,
#  10.0,
#  37.0,
#  26.0,
#  1.5,
#  25.0,
#  18.0,
#  230.0,
#  12.0,
#  12.0,
#  45.0,
#  18.0,
#  54.0,
#  57.5,
#  14.0,
#  120.0,
#  7000000,
#  65.0,
#  5.0,
#  20.0,
#  25.0,
#  20.0,
#  20.0,
#  225.0,
#  160.0,
#  185.0,
#  80.0,
#  12.0,
#  55.0,
#  25.0,
#  15.0,
#  137.5,
#  14.0,
#  40.0,
#  32.5,
#  11.0,
#  27.0,
#  9.0,
#  60.0,
#  16.0,
#  6.0,
#  20000000,
#  15.0,
#  90.0,
#  37.0,
#  90.0,
#  16.0,
#  180.0,
#  2.0,
#  75.0,
#  27.5,
#  0.3,
#  35.0,
#  50.0,
#  2100000,
#  22.5,
#  15.0,
#  48.0,
#  30.0,
#  30.0,
#  45.0,
#  30.0,
#  16.5,
#  150.0,
#  61.0,
#  25.0,
#  8.0,
#  12.0,
#  75.0,
#  21.0,
#  2.75,
#  20.0,
#  50.0,
#  85.0,
#  120.0,
#  19.0,
#  75.0,
#  15.0,
#  50.0,
#  150.0,
#  17.5,
#  7.5,
#  16.0,
#  25.0,
#  150.0,
#  20.0,
#  7.0,
#  27.5,
#  12.5,
#  110.0,
#  21.5,
#  40.0,
#  25.0,
#  28.0,
#  0.45,
#  7.3,
#  300.0,
#  20.0,
#  150.0,
#  45.0,
#  180.0,
#  60.0,
#  160.0,
#  11.4,
#  70.0,
#  40.0,
#  17.5,
#  16.5,
#  2.0,
#  45.0,
#  205.0,
#  20.0,
#  200000,
#  16.0,
#  13.0,
#  32.0,
#  9.0,
#  0.05,
#  72.5,
#  4.0,
#  25.0,
#  35.0,
#  151.0,
#  6.54,
#  1.5,
#  28.0,
#  10000000,
#  60.0,
#  20.0,
#  8.0,
#  12.0,
#  35000000,
#  9.0,
#  100.0,
#  8.0,
#  18.0,
#  4.0,
#  70.0,
#  102.0,
#  76.0,
#  5.0,
#  12.0,
#  2.0,
#  30.0,
#  16.0,
#  100.0,
#  8.0,
#  25.0,
#  149.0,
#  12.0,
#  6.5,
#  75.0,
#  15.0,
#  50.0,
#  11.0,
#  75.0,
#  45.0,
#  13.0,
#  14.0,
#  8.0,
#  825000,
#  27.0,
#  20.0,
#  40.0,
#  30.0,
#  75.0,
#  32.0,
#  110.0,
#  27.5,
#  0.15,
#  85.0,
#  13.0,
#  63.7,
#  225.0,
#  160.0,
#  0.4,
#  5.3,
#  12.0,
#  25.0,
#  2.0,
#  2.0,
#  50.0,
#  15.25,
#  17.0,
#  33.0,
#  17.0,
#  20.0,
#  30.0,
#  232.0,
#  30.0,
#  45.0,
#  52.0,
#  125.0,
#  3.3,
#  90.0,
#  35.0,
#  35.0,
#  20.0,
#  3.7,
#  85.0,
#  50.0,
#  16.5,
#  40.0,
#  19.4,
#  40.0,
#  55.0,
#  15.0,
#  8.3,
#  30.0,
#  9.4,
#  65.0,
#  15.0,
#  1.0,
#  210.0,
#  54.0,
#  35.0,
#  22.0,
#  55.0,
#  30.0,
#  150.0,
#  25.0,
#  80.0,
#  25.0,
#  20.0,
#  2.9,
#  0.45,
#  13.9,
#  7.0,
#  150.0,
#  4.5,
#  88.0,
#  45.0,
#  75.0,
#  0.45,
#  30.0,
#  35.0,
#  43.0,
#  60.0,
#  8.0,
#  50.0,
#  70.0,
#  87.5,
#  55.0,
#  140.0,
#  7.0,
#  0.95,
#  150.0,
#  50.0,
#  25.0,
#  55.0,
#  17.5,
#  4.8,
#  2.8,
#  25.0,
#  72.0,
#  1.0,
#  58.0,
#  207.0,
#  110.0,
#  15.0,
#  42.0,
#  75.0,
#  50.0,
#  15.0,
#  2.0,
#  85.0,
#  4.0,
#  60.0,
#  110.0,
#  75.0,
#  30.0,
#  65.0,
#  28.0,
#  20.0,
#  26.0,
#  40.0,
#  80.0,
#  5.0,
#  39.0,
#  7.5,
#  40.0,
#  0.3,
#  60.0,
#  100.0,
#  115.0,
#  138.0,
#  2.0,
#  7.5,
#  26.0,
#  50.0,
#  18.5,
#  1.5,
#  180.0,
#  25.5,
#  7.0,
#  7.0,
#  18.0,
#  18.0,
#  45.0,
#  120.0,
#  28.5,
#  80.0,
#  30.0,
#  50.0,
#  40.0,
#  1.5,
#  15.0,
#  1.0,
#  4.75,
#  50.0,
#  1.12,
#  29.0,
#  132.0,
#  3.0,
#  10.0,
#  45.0,
#  65.0,
#  30.0,
#  12.0,
#  75.0,
#  19.0,
#  6.5,
#  55.0,
#  25.0,
#  110.0,
#  70.0,
#  15.0,
#  2.0,
#  50.0,
#  100.0,
#  45.0,
#  35.0,
#  60.0,
#  20.0,
#  7.3,
#  3.5,
#  28.0,
#  30.0,
#  35.0,
#  20.0,
#  10.0,
#  25.0,
#  75.0,
#  2.5,
#  9.0,
#  130.0,
#  60.0,
#  110.0,
#  22.0,
#  105.0,
#  26.0,
#  11.0,
#  20.0,
#  6.5,
#  100.0,
#  3.2,
#  18.0,
#  30.0,
#  28.0,
#  1.7,
#  0.4,
#  40.0,
#  0.01,
#  50.0,
#  40.0,
#  50.0,
#  5.0,
#  1.2,
#  40.0,
#  75.0,
#  5.0,
#  70.0,
#  17.0,
#  70.0,
#  75.0,
#  200.0,
#  20.0,
#  110.0,
#  85.0,
#  13.0,
#  120.0,
#  125.0,
#  10.0,
#  92.0,
#  50.0,
#  30.0,
#  55.0,
#  170.0,
#  45.0,
#  100.0,
#  75.0,
#  ...]

# %%
rss_consultant(scaled_movies) # 23234357.68
# Out:
# 8875214.88

# %% [markdown]
# Ok, we'll find out if this number is any good later, but for right now let's just say that our RSS is good enough.  Use the derivative to write a function that provided a budget, returns the $\frac{\Delta R}{\Delta x}$ according to the consultant's model.  Remember that our consultant's model is $R(x) = 1.5x + 10$ where $x$ is a budget, and $R(x)$ is an expected revenue.

# %% [markdown]
# ### A new model

# %% [markdown]
# Now imagine a data scientist in your company wants to take a crack at his own model for predicting a movie's revenue.  The data scientist notices, that in general, movies tend to make more money per year.

# %%
from graph import build_layout
years = list(map(lambda movie: movie['year'],movies))
years_and_revenues = trace_values(years, domestic_revenues, text = titles)
years_layout = build_layout(y_range = [0, 550])
plot([years_and_revenues], years_layout)

# %% [markdown]
# So the data scientist comes up with a new model, to indicate a movie's expected revenue is 1.5 million for every year after 1965 plus 1.1 times the movie's budget.  Write a function called `revenue_with_year` that takes as arguments `budget` and `year` and returns expected revenue.

# %%
def revenue_with_year(budget, year):
    pass

# %%
revenue_with_year(25, 1997) # 75.5
revenue_with_year(40, 1983) # 71.0

# %% [markdown]
# Notice that this model has **two variables**, the budget and year, and therefore is not a line function.  Let's compare these models by plotting the actual revenues and budgets, the prior `external consultant estimate` line trace, and the `internal consultant estimate` based upon this model's estimates.  Since this model doesn't produce a line, we will set the mode for `internal_consultant_estimated_trace` to 'markers'.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))
titles = list(map(lambda movie: movie['title'], scaled_movies))

internal_consultant_estimated_revenues = list(map(lambda movie: revenue_with_year(movie['budget_2013$'], movie['year']),scaled_movies))
internal_consultant_estimated_trace = trace_values(budgets, internal_consultant_estimated_revenues, mode='markers', name = 'internal consultant estimate')

# %%
internal_consultant_estimated_trace['x'][0:10] # [13.0, 45.66, 20.0, 61.0, 40.0, 225.0, 92.0, 12.0, 13.0, 130.0]
internal_consultant_estimated_trace['y'][0:10] # [86.3, 120.726, 94.0, 139.10000000000002, 116.0, 319.5, 173.2, 85.2, 86.3, 215.0]
internal_consultant_estimated_trace['mode'] # 'markers'

# %%
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)

from graph import trace_values, m_b_trace, plot
plot([revenues_per_budgets_trace, consultant_estimated_revenues_trace, internal_consultant_estimated_trace], revenues_layout)

# %% [markdown]
# Although the `external consultant model` isn't a line, it still seems to match our data fairly well.  Let's find out how well.  Even though it is not a line, we can still calculate the RSS for this model.  Write a function called `rss_revenue_with_year` that returns the Residual Sum of Squares associated with the `revenue_with_year` model for the `scaled_movies` dataset.  The `squared_error_revenue_with_year` function can be used to return the squared error of the model associated with just a single movie.

# %%
def squared_error_revenue_with_year(movie):
    pass

def rss_revenue_with_year(movies):
    pass

# %%
rss_revenue_with_year(scaled_movies) # 25364329.23

# %% [markdown]
# The RSS here is $25,364,329.23$ as opposed to the RSS of $23,234,357.68$ from the external consultant's model.  According to RSS, this model isn't as accurate as the previous model. Still, it isn't bad enough to ignore completely.

# %% [markdown]
# ### Our initial regression line, and improving upon it

# %% [markdown]
# Now that we have evaluated the models of an outside consultant and an internal consultant, it's time to see if we can do any better.  Let's go.

# %% [markdown]
# We have our dataset. Let's begin with an initial regression line that sets $b = .5$ and $m = 1.79$.

# %%
from linear_equations import build_regression_line
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies)) or [1, 2]
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies)) or [1, 2]

# %%
initial_regression_line = {'b': 0.5, 'm': 1.79}

# %% [markdown]
# Using values for $m$ and $b$ from our initial regression line, we can write `expected_revenue_per_budget` that returns the expected revenue provided a budget.

# %%
def expected_revenue_per_budget(budget):
    pass

# %%
budget = american_hustle['budget_2013$'] # 40.0
expected_revenue_per_budget(budget) # 72.1

# %% [markdown]
# Now this initial regression line was not very sophisticated. We simply drew a line between the points with the lowest and highest $x$ values.
#
# Let's plot our initial regression line along our dataset to get a sense of the accuracy of this first line.

# %%
budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
estimated_revenues = list(map(lambda budget: expected_revenue_per_budget(budget), budgets))
len(estimated_revenues)
initial_regression_trace = trace_values(budgets, estimated_revenues, mode = 'line', name = 'initial regression trace')

# %%
plot([revenues_per_budgets_trace, initial_regression_trace], revenues_layout)

# %% [markdown]
# By now we should be able to guess the next step: quantify how well this line matches our data.  We'll write a function called `regression_revenue_error` that, provided a movie and an `m` and `b` value of a regression line, returns the difference between our `initial_regression_lines`'s expected revenue and the actual revenue error.

# %%
def regression_revenue_error(m, b, movie):
    pass

# %%
initial_regression_line

# %%
american_hustle = {'binary': 'PASS', 'budget': 40.0, 'budget_2013$': 40.0, 'clean_test': 'ok',
         'code': '2013PASS', 'decade code': 1.0, 'domgross': 148.43, 'domgross_2013$': 148.43, 'imdb': 'tt1800241',
         'intgross': 249.48, 'intgross_2013$': 249.48, 'period code': 1.0, 'test': 'ok-disagree',
         'title': 'American Hustle', 'year': 2013}

regression_revenue_error(initial_regression_line['m'], initial_regression_line['b'], american_hustle)
# 76.33

# %% [markdown]
# Ok, now plot the cost curve from changing values of $m$ from $1.0$ to $1.9$.
#
# > We don't ask you to write a function for calculating the RSS, as you already wrote one in the error library which is available to you, and you can see used here.

# %%
from error import residual_sum_squares
residual_sum_squares(budgets, domestic_revenues, initial_regression_line['m'], initial_regression_line['b'])

# %% [markdown]
# But we do ask you to plot a cost curve from 1.0, to 1.9 using that `residual_sum_squares` function. We start off with a list of values of m from 1.0 to 1.9, assigned to `m_range` below.

# %%
large_m_range = list(range(10, 20))
m_range = list(map(lambda m_value: m_value/10,large_m_range))

# %% [markdown]
# Now we need to calculate a list of RSS values associated with each value in the `m_range`.

# %%
cost_values = list(map(lambda m_value: round(residual_sum_squares(budgets, domestic_revenues, m_value, initial_regression_line['b']), 2),m_range))

# %%
from graph import trace_values
rss_trace = trace_values(x_values=m_range, y_values=cost_values, mode = 'line')

# %%
rss_trace

# %%
plot([rss_trace])

# %% [markdown]
# Ok, so based on this, it appears that with our $b = 0.5$, the slope of our regression line that produces the lowest error is between $1.3$ and $1.4$. In fact if we replace our initial line value of $m$ with $1.3$, we see that our RSS does in fact decline from our previous value of $24,179,824$.

# %%
residual_sum_squares(budgets, domestic_revenues, 1.3, initial_regression_line['b'])

# %% [markdown]
# ### Changing multiple variables

# %% [markdown]
# Ok, now it's time to move beyond testing the accuracy of the line with changing only a single variable.  We need to play with both variables to find the 'best fit regression line'. As we know, the technique for that is to use gradient descent.
#
# Remember that we derived our gradient formulas by starting with our cost function, and saying the RSS is a function of our $m$ and $b$ variables:

# %% [markdown]
# $$J(m,b) = \sum_{i = 1}^n(y_i - (mx_i + b))^2 $$

# %% [markdown]
# From the above formula for our cost curve, we found the gradient descent of the cost function, as that is used to find the incremental changes to decrease RSS. We do this mathematically, by taking the partial derivative with respect to $m$ and $b$.
#
# $$ \frac{dJ}{db}J(m,b) = -2\sum_{i = 1}^n(y_i - (mx_i + b)) = -2\sum_{i = 1}^n \epsilon_i $$
# $$ \frac{dJ}{dm}J(m,b) = -2\sum_{i = 1}^n x(y_i - (mx_i + b)) = -2\sum_{i = 1}^n x_i*\epsilon_i$$

# %% [markdown]
# Looking at our top function $\frac{dJ}{dm}$, we see that it equals negative 2, multiplied by the sum of the errors for a provided $m$ and $b$ values relative to our dataset.  And luckily for us, we already have a function called `regression_revenue_error` that returns the error at a given point when provided our $m$ and $b$ values.
#
# Our task now is two write a function called `b_gradient` that takes in values of $m$, $b$ and our (scaled) movies, and returns the `b` gradient, which is -2 times the sum of the errors for the dataset.

# %%
def b_gradient(m, b, movies):
    pass

# %%
b_gradient(1.79, 0.50, scaled_movies) # 5.37

# %% [markdown]
# Next, write a function called `m_gradient` that returns the `m` gradient for values of $m$, $b$, and a list of movies.

# %%
def m_gradient(m, b, movies):
    pass

# %%
m_gradient(1.79, 0.50, scaled_movies) # 2520.59

# %% [markdown]
# > Notice that the `m_gradient` is significantly larger than the `b_gradient`. This makes sense since the `m_gradient` formula is similar to the `b_gradient` formula, except that its output is also multiplied by the corresponding $x$ value.

# %% [markdown]
# Ok, now we just wrote two functions that tell us how to update the corresponding values of $m$ and $b$.  Our next step is to write a function called `step_gradient` that will use these functions to take the step down along our cost curve.
#
# Remember that with each step we want to move our `current_b` value in the negative direction of calculated `b_gradient`, and want to move our `current_m` value in the negative direction of the calculated `m_gradient`.
#
# `current_m` = `old_m` $ -  \eta(-2*\sum_{i=1}^n x_i*\epsilon_i )$
#
# `current_b` =  `old_b` $ - \eta( -2*\sum_{i=1}^n \epsilon_i )$
#
# The `step_gradient` function would take as arguments the `b_current`, `m_current`, the list of scaled movies, and a learning rate, and returns a newly calculated `b_current` and `m_current` with a dictionary of keys `b` and `m` that point to the current values.

# %%
def step_gradient(b_current, m_current, movies, learning_rate):
    pass

# %%
initial_regression_line # {'b': 0.5, 'm': 1.79}

# %% [markdown]
# Then let's see how our formula changes over time using gradient descent.

# %%
step_gradient(initial_regression_line['b'], initial_regression_line['m'], scaled_movies, .0001)

# %% [markdown]
# Now write a function that can operate given a set of 100 iterations and start from our `initial_regression_line`.

# %%
# set our initial step with m and b values, and the corresponding error.
def generate_steps(m, b, number_of_steps, movies, learning_rate):
    pass

#     iterations = []
#     for i in range(number_of_steps):
#         iteration = step_gradient(b, m, movies, learning_rate)
#         # {'b': value, 'm': value}
#         b = iteration['b']
#         m = iteration['m']
#         # update values of b and m
#         iterations.append(iteration)
#     return iterations

# %%
iterations = generate_steps(initial_regression_line['b'], initial_regression_line['m'], 100, scaled_movies, .0001) or [{'m': 'uncomment generate_steps method', 'b': 'uncomment generate_steps method '}]

# %% [markdown]
# And we can see how this changes over time.

# %%
def to_line(m, b):
    initial_x = 0
    ending_x = 500
    initial_y = m*initial_x + b
    ending_y = m*ending_x + b
    return {'data': [{'x': [initial_x, ending_x], 'y': [initial_y, ending_y]}]}

frames = list(map(lambda iteration: to_line(iteration['m'], iteration['b']),iterations))

# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML

init_notebook_mode(connected=True)

budgets = list(map(lambda movie: movie['budget_2013$'], scaled_movies))
domestic_revenues = list(map(lambda movie: movie['domgross_2013$'], scaled_movies))

figure = {'data': [{'x': [0], 'y': [0]}, {'x': budgets, 'y': domestic_revenues, 'mode': 'markers'}],
          'layout': {'title': 'Regression Line',
                     'updatemenus': [{'type': 'buttons',
                                      'buttons': [{'label': 'Play',
                                                   'method': 'animate',
                                                   'args': [None]}]}]
                    },
          'frames': frames}
iplot(figure)

# %% [markdown]
# Finally, let's calculate the RSS associated with our formula as opposed to the other.

# %%
iterations[-1] # {'b': 1.8, 'm': 1.37}

# %%
residual_sum_squares(budgets, domestic_revenues, iterations[-1]['m'], iterations[-1]['b'])

# %% [markdown]
# Using this last iteration, we have an RSS $21,982,786$, better than all previous models - and we have the data, and knowledge to prove it:

# %%
external_consultant_model = rss_consultant(scaled_movies)
internal_consultant_model = rss_revenue_with_year(scaled_movies)
our_regression_model = residual_sum_squares(budgets, domestic_revenues, iterations[-1]['m'], iterations[-1]['b'])

# %%
external_consultant_model # 23234357.68
internal_consultant_model # 25364329.23
our_regression_model      # 21982786.34
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-19a0f8024381> in <module>()
# ----> 1 external_consultant_model # 23234357.68
#       2 internal_consultant_model # 25364329.23
#       3 our_regression_model      # 21982786.34
#
# NameError: name 'external_consultant_model' is not defined

# %%
import pandas

def parse_file(fileName):
    kickstarter_df = pandas.read_csv(fileName)
    return kickstarter_df.to_dict('records')

movies = parse_file('../../../')
# Out:
# ParserErrorTraceback (most recent call last)
# <ipython-input-9-c2a75703f8b9> in <module>()
#       5     return kickstarter_df.to_dict('records')
#       6
# ----> 7 movies = parse_file('https://drive.google.com/file/d/0By26wLpAqHfQaF9Jb19RUFVnNjA/view?usp=sharing')
#
# <ipython-input-9-c2a75703f8b9> in parse_file(fileName)
#       2
#       3 def parse_file(fileName):
# ----> 4     kickstarter_df = pandas.read_csv(fileName)
#       5     return kickstarter_df.to_dict('records')
#       6
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 10 fields in line 10, saw 14

# %% [markdown]
# Nice work!
